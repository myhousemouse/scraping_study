# %% [markdown]
# <a href="https://colab.research.google.com/github/myhousemouse/scraping_study/blob/main/indibook_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 인디펍 > 책 제목

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}
all_book_titles = [] # 모든 페이지의 책 제목을 저장할 리스트

for page_num in range(10, 15): # 10페이지부터 14페이지까지 반복
    url = f'https://indiepub.kr/product/list.html?cate_no=24&page={page_num}'
    print(f"스크래핑 중: {url}") # 현재 스크래핑 중인 페이지 출력

    try:
        data = requests.get(url, headers=headers)
        data.raise_for_status() # HTTP 오류 발생 시 예외 발생

        soup = BeautifulSoup(data.text, 'html.parser')

        # 책 제목을 포함하는 두 번째 span 태그를 직접 선택하는 셀렉터
        book_title_selector = 'div.name > a > span:nth-of-type(2)'

        title_elements = soup.select(book_title_selector)

        for title_element in title_elements:
            title = title_element.get_text(strip=True)
            all_book_titles.append(title)

    except requests.exceptions.RequestException as e:
        print(f"요청 오류 발생: {e} (URL: {url})")
        continue # 오류 발생 시 다음 페이지로 건너뛰기

# 추출된 모든 책 제목 출력
print("\n--- 추출된 모든 책 제목 ---")
for title in all_book_titles:
    print(title)

print(f"\n총 {len(all_book_titles)}개의 책 제목을 추출했습니다.")
# Out:
# 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=10
# 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=11
# 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=12
# 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=13
# 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=14
#
# --- 추출된 모든 책 제목 ---
# 이러나저러나 불편한 거야 불편한 건
# 불안과 밤 산책
# 속속들이 독립출판 알고 보니 의존 출판
# A ROOM OF FACE TO FACE
# Savemyself09!
# (은/는/이/가) 당신을 사랑한다
# 반짝이는 나의 계절
# 기숙사에 재고만이 쌓였습니다
# 아름다운 이 세상은 우리를 시인으로 만들었지
# 오늘의문예비평 136호
# MTB로 백두대간과 9정맥
# 일상의 재발견
# 잘 될 거야 같은 소리 하네
# 나는 괴물입니다
# 작은방 한켠 나의 트레킹 가방
# CONCEPTZINE vol.124
# 부라보 마이 라이프
# 아날로그
# 마음챙김 플라워 힐링북
# 울지마
# Small Brand, High value
# 일시 정지 후 재생
# 엉망진창인채로 40대, 오히려 좋아
# 외계행성 다방유랑기
# 즉흥 연주를 위한 실전 코드 사전
# 기타 연습 가이드북
# 조각난 기억, 사랑으로 남다
# 사탄탱고: 벨라 타르에 들어가기 앞서
# Two Of A Kind
# 퇴사 후, 치앙마이
# 기억나무
# 새벽 죽음 연습
# 뇌경색 환자의 좌충우돌 1인 출판사 창업기
# 로컬 매거진 인천 스펙타클(spectacle) : 05 술술 읽히는 인천의 술
# 넘어졌던 자리에서 다시 걸을 수 있다면 정말 괜찮습니다
# 로자 룩셈부르크
# 여름으로 지어진 곳
# 닻
# 알을 두고 온 새의 마음
# 살아있는 보물지도의 비밀
# 들켜도 망하지 않았으면 좋겠다
# 긍정샐러드
# 파란인
# 파도에 지워진 어부의 시
# 달팽이의 슬픔
# 그래서... 제목이 뭔데? 2
# 내 이야기가 책이 되는 순간
# 고로 존재한다
# 사유하라
# 쓰기로 다시 시작
# 자유형을 완벽하게 하는 방법
# 대머리는 수영모를 쓰지 않는다
# 강아지책
# 서성이는 발걸음
# 파도보다 더 높이
# 하루와 클로버
# 색을 짓다
# 마음을 담아, 당신에게 응원을 건네요
# 굳이, 서울
# 나의 독립출판은 지속될 수 있을까
# 늘 같은 자리를 맴도는 한낮의 달처럼
# CONCEPTZINE vol.123
# 저도 알고 싶지 않았습니다
# 우리가 슬쩍 본 도시 스톡홀름, 헬싱키
# 용기를 내어 일어서라
# 우울하기엔 오늘의 내가 너무 빛나서
# 아임 이너프 - I'm enough
# 엄마로 눈부신 순간
# 당신을 응원합니다 당신이 최고입니다 자랑스럽습니다
# 몽매한 풀잎은 그 봄을 기억한다
# 28일 플랜
# 초보 사장의 특별한맛주식회사 경영기
# 대통령제의 종언
# 빌어먹을 필라테스
# 어른이 되어 가는 과정
# 리타의 산책
# 메무와 무지개 탐험
# 잠적
# 내가 지금, 여기
# 마음의 위상
# 청소 (월간옥키52)
# WALK TOKYO
# WALK PARIS
# 까미노의 말
# 염재현의 지구촌 이야기
# 정말 잘 지내나요 사실 난 울고 있는데
# 극야일기
# 만다라로 자기 돌봄
# 네가 원한다면 망설일 필요 없어
# 쓸수록 돈이 된다
# 갑상선암에 걸리면 스카프 쇼핑부터 하는 게 좋다
# 훌쩍대지 말고 훌쩍 떠나
# 커피 앞에서 쓰기
# 내가 널 생각할 때마다 별들이 빛난다면
# 혼잣말 모임
# 도대체 책방이 뭐라고
# 개와 고양이, 오래된 신문을 펼치다
# Fragments of the Past
# 수상한 양말
# CONCEPTZINE vol.122
# 도망치듯 사랑을 말한다면
# 유독 내가 싫은 날
# 아차어차여차하면 달라지는 단어들 : 일상의 재구성
# 아차어차여차하면 달라지는 단어들 : 관계의 재구성
# 먹는다의 디자인
# 적어도 둘이라 좋아
# 4주완성! 쉬운데 그럴싸한 디지털드로잉
# 4주완성! 쉬운데 그럴싸한 디지털드로잉
# 열매를 맺기 위해 준비하는
# 해를 쫓는 아이들
# 머어얼리
# 날씨 '소나기'
# 깨어난 자유
# 매달리는 기쁨
# 마음을 안는 마음
# 樂, STEP - 요즘엔 스윙댄스를 추고 있습니다
# 산책가자
# 일기를 쓰려는데 아무일도 없었어
# 떠나고, 남았다
# 어쩐지 제주에 오고 싶었어
#
# 총 120개의 책 제목을 추출했습니다.

# %% [markdown]
# # 인디펍 > 책 > 상세 페이지

# %%
import requests
from bs4 import BeautifulSoup

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}
detail_page_urls = [] # 상세 페이지 URL을 저장할 리스트

# 목록 페이지 URL (일단 첫 페이지부터 시작) 추후 모든 페이지로 변경
# list_page_url = 'https://indiepub.kr/product/list.html?cate_no=24&page=10' # 기존 코드 주석 처리

for page_num in range(10, 15): # 10페이지부터 14페이지까지 반복
    list_page_url = f'https://indiepub.kr/product/list.html?cate_no=24&page={page_num}'
    print(f"목록 페이지 스크래핑 중: {list_page_url}")

    try:
        data = requests.get(list_page_url, headers=headers)
        data.raise_for_status() # HTTP 오류 발생 시 예외 발생

        soup = BeautifulSoup(data.text, 'html.parser')
        product_link_selector = 'div.prdImg > a' # 상품 이미지 링크를 포함하는 a 태그

        link_elements = soup.select(product_link_selector)

        for link_element in link_elements:
            # href 속성에서 상세 페이지 URL 추출
            detail_url = link_element.get('href')
            if detail_url:
                # 상대 경로인 경우 절대 경로로 변환
                if detail_url.startswith('/'):
                    detail_url = f'https://indiepub.kr{detail_url}'
                detail_page_urls.append(detail_url)

    except requests.exceptions.RequestException as e:
        print(f"요청 오류 발생: {e} (URL: {list_page_url})")
        continue # 오류 발생 시 다음 페이지로 건너뛰기


# 추출된 상세 페이지 URL 출력
print("\n--- 추출된 상세 페이지 URL ---")
# 추출된 URL이 많을 수 있으므로 처음 20개만 출력하거나 길이를 출력
if len(detail_page_urls) > 20:
    for url in detail_page_urls[:20]:
        print(url)
    print("...") # 생략 기호
else:
    for url in detail_page_urls:
        print(url)


print(f"\n총 {len(detail_page_urls)}개의 상세 페이지 URL을 추출했습니다.")
# Out:
# 목록 페이지 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=10
# 목록 페이지 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=11
# 목록 페이지 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=12
# 목록 페이지 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=13
# 목록 페이지 스크래핑 중: https://indiepub.kr/product/list.html?cate_no=24&page=14
#
# --- 추출된 상세 페이지 URL ---
# https://indiepub.kr/product/이러나저러나-불편한-거야-불편한-건/8363/category/24/display/1/
# https://indiepub.kr/product/불안과-밤-산책/8360/category/24/display/1/
# https://indiepub.kr/product/속속들이-독립출판-알고-보니-의존-출판/8357/category/24/display/1/
# https://indiepub.kr/product/a-room-of-face-to-face/8356/category/24/display/1/
# https://indiepub.kr/product/savemyself09/8353/category/24/display/1/
# https://indiepub.kr/product/은는이가-당신을-사랑한다/8350/category/24/display/1/
# https://indiepub.kr/product/반짝이는-나의-계절/8347/category/24/display/1/
# https://indiepub.kr/product/기숙사에-재고만이-쌓였습니다/8344/category/24/display/1/
# https://indiepub.kr/product/아름다운-이-세상은-우리를-시인으로-만들었지/8342/category/24/display/1/
# https://indiepub.kr/product/오늘의문예비평-136호/8340/category/24/display/1/
# https://indiepub.kr/product/mtb로-백두대간과-9정맥/8338/category/24/display/1/
# https://indiepub.kr/product/일상의-재발견/8335/category/24/display/1/
# https://indiepub.kr/product/잘-될-거야-같은-소리-하네/8334/category/24/display/1/
# https://indiepub.kr/product/나는-괴물입니다/8332/category/24/display/1/
# https://indiepub.kr/product/작은방-한켠-나의-트레킹-가방/8330/category/24/display/1/
# https://indiepub.kr/product/conceptzine-vol124/8328/category/24/display/1/
# https://indiepub.kr/product/부라보-마이-라이프/8326/category/24/display/1/
# https://indiepub.kr/product/아날로그/8323/category/24/display/1/
# https://indiepub.kr/product/마음챙김-플라워-힐링북/8320/category/24/display/1/
# https://indiepub.kr/product/울지마/8318/category/24/display/1/
# ...
#
# 총 120개의 상세 페이지 URL을 추출했습니다.

# %% [markdown]
# # 인디펍 > 상세 페이지 > 책 제목 & 책 한줄소개 & 요약글 스크래핑

# %%
import requests
from bs4 import BeautifulSoup

# 셀 89ddbf1f에서 추출한 상세 페이지 URL 목록을 사용합니다.
# detail_page_urls 변수에 상세 페이지 URL들이 저장되어 있어야 함.
# 모든 책의 상세 정보를 저장할 리스트
all_book_details = []

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'}

# 추출된 상세 페이지 URL 목록을 순회합니다.
for detail_url in detail_page_urls:
    print(f"상세 페이지 스크래핑 중: {detail_url}")

    try:
        data = requests.get(detail_url, headers=headers)
        data.raise_for_status() # HTTP 오류 발생 시 예외 발생

        soup = BeautifulSoup(data.text, 'html.parser')

        # 사용자가 제공한 CSS 셀렉터를 사용하여 정보 추출
        # 책 제목 셀렉터
        title_selector = '#contents > div > div.xans-element-.xans-product.xans-product-detail.timesale-active > div.detailArea > div.infoArea > div.headingArea > h1'
        # 책 한 줄 소개글 셀렉터
        summary_desc_selector = '#contents > div > div.xans-element-.xans-product.xans-product-detail.timesale-active > div.detailArea > div.infoArea > div.headingArea > div.summary_desc_css'
        # 책 요약글 셀렉터
        summary_selector = '#prdDetail > div.cont > div:nth-child(5) > p'

        # 각 정보 추출 시 None이 반환될 수 있으므로 확인 필요
        book_title_element = soup.select_one(title_selector)
        book_summary_desc_element = soup.select_one(summary_desc_selector)
        book_summary_element = soup.select_one(summary_selector)

        book_title = book_title_element.get_text(strip=True) if book_title_element else "N/A"
        book_summary_desc = book_summary_desc_element.get_text(strip=True) if book_summary_desc_element else "N/A"
        book_summary = book_summary_element.get_text(strip=True) if book_summary_element else "N/A"

        # 추출한 정보를 딕셔너리로 저장
        book_details = {
            "URL": detail_url,
            "제목": book_title,
            "한 줄 소개": book_summary_desc,
            "요약글": book_summary
        }
        all_book_details.append(book_details)

    except requests.exceptions.RequestException as e:
        print(f"요청 오류 발생: {e} (URL: {detail_url})")
        continue # 오류 발생 시 다음 URL로 건너뛰기
    except Exception as e:
        print(f"스크래핑 중 알 수 없는 오류 발생: {e} (URL: {detail_url})")
        continue # 다른 오류 발생 시 다음 URL로 건너뛰기


# 추출된 모든 상세 정보 출력
print("\n--- 추출된 모든 책 상세 정보 ---")
for book in all_book_details:
    print(f"URL: {book['URL']}")
    print(f"제목: {book['제목']}")
    print(f"한 줄 소개: {book['한 줄 소개']}")
    print(f"요약글: {book['요약글']}")
    print("-" * 20) # 구분선 출력

print(f"\n총 {len(all_book_details)}개의 책 상세 정보를 추출했습니다.")
# Out:
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/이러나저러나-불편한-거야-불편한-건/8363/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/불안과-밤-산책/8360/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/속속들이-독립출판-알고-보니-의존-출판/8357/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/a-room-of-face-to-face/8356/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/savemyself09/8353/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/은는이가-당신을-사랑한다/8350/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/반짝이는-나의-계절/8347/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/기숙사에-재고만이-쌓였습니다/8344/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/아름다운-이-세상은-우리를-시인으로-만들었지/8342/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/오늘의문예비평-136호/8340/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/mtb로-백두대간과-9정맥/8338/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/일상의-재발견/8335/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/잘-될-거야-같은-소리-하네/8334/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/나는-괴물입니다/8332/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/작은방-한켠-나의-트레킹-가방/8330/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/conceptzine-vol124/8328/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/부라보-마이-라이프/8326/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/아날로그/8323/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/마음챙김-플라워-힐링북/8320/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/울지마/8318/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/small-brand-high-value/8316/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/일시-정지-후-재생/8313/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/엉망진창인채로-40대-오히려-좋아/8310/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/외계행성-다방유랑기/8308/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/즉흥-연주를-위한-실전-코드-사전/8307/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/기타-연습-가이드북/8305/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/조각난-기억-사랑으로-남다/8302/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/사탄탱고-벨라-타르에-들어가기-앞서/8298/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/two-of-a-kind/8297/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/퇴사-후-치앙마이/8296/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/기억나무/8294/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/새벽-죽음-연습/8291/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/뇌경색-환자의-좌충우돌-1인-출판사-창업기/8288/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/로컬-매거진-인천-스펙타클spectacle-05-술술-읽히는-인천의-술/8286/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/넘어졌던-자리에서-다시-걸을-수-있다면-정말-괜찮습니다/8279/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/로자-룩셈부르크/8276/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/여름으로-지어진-곳/8273/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/닻/8270/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/알을-두고-온-새의-마음/8269/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/살아있는-보물지도의-비밀/8267/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/들켜도-망하지-않았으면-좋겠다/8265/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/긍정샐러드/8259/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/파란인/8256/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/파도에-지워진-어부의-시/8252/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/달팽이의-슬픔/8247/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/그래서-제목이-뭔데-2/8244/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/내-이야기가-책이-되는-순간/8241/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/고로-존재한다/8239/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/사유하라/8238/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/쓰기로-다시-시작/8235/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/자유형을-완벽하게-하는-방법/8230/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/대머리는-수영모를-쓰지-않는다/8227/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/강아지책/8218/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/서성이는-발걸음/8215/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/파도보다-더-높이/8214/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/하루와-클로버/8211/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/색을-짓다/8208/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/마음을-담아-당신에게-응원을-건네요/8205/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/굳이-서울/8203/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/나의-독립출판은-지속될-수-있을까/8201/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/늘-같은-자리를-맴도는-한낮의-달처럼/8198/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/conceptzine-vol123/8196/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/저도-알고-싶지-않았습니다/8195/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/우리가-슬쩍-본-도시-스톡홀름-헬싱키/8193/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/용기를-내어-일어서라/8191/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/우울하기엔-오늘의-내가-너무-빛나서/8189/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/아임-이너프-im-enough/8186/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/엄마로-눈부신-순간/8183/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/당신을-응원합니다-당신이-최고입니다-자랑스럽습니다/8174/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/몽매한-풀잎은-그-봄을-기억한다/8170/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/28일-플랜/8168/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/초보-사장의-특별한맛주식회사-경영기/8165/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/대통령제의-종언/8162/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/빌어먹을-필라테스/8159/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/어른이-되어-가는-과정/8158/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/리타의-산책/8157/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/메무와-무지개-탐험/8154/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/잠적/8152/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/내가-지금-여기/8150/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/마음의-위상/8147/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/청소-월간옥키52/8145/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/walk-tokyo/8144/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/walk-paris/8143/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/까미노의-말/8142/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/염재현의-지구촌-이야기/8141/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/정말-잘-지내나요-사실-난-울고-있는데/8140/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/극야일기/8137/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/만다라로-자기-돌봄/8135/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/네가-원한다면-망설일-필요-없어/8132/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/쓸수록-돈이-된다/8130/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/갑상선암에-걸리면-스카프-쇼핑부터-하는-게-좋다/8129/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/훌쩍대지-말고-훌쩍-떠나/8120/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/커피-앞에서-쓰기/8117/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/내가-널-생각할-때마다-별들이-빛난다면/8115/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/혼잣말-모임/8114/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/도대체-책방이-뭐라고/8113/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/개와-고양이-오래된-신문을-펼치다/8111/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/fragments-of-the-past/8109/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/수상한-양말/8107/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/conceptzine-vol122/8105/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/도망치듯-사랑을-말한다면/8104/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/유독-내가-싫은-날/8102/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/아차어차여차하면-달라지는-단어들-일상의-재구성/8098/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/아차어차여차하면-달라지는-단어들-관계의-재구성/8095/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/먹는다의-디자인/8092/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/적어도-둘이라-좋아/8091/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/4주완성-쉬운데-그럴싸한-디지털드로잉/8087/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/4주완성-쉬운데-그럴싸한-디지털드로잉/8084/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/열매를-맺기-위해-준비하는/8082/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/해를-쫓는-아이들/8080/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/머어얼리/8079/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/날씨-소나기/8076/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/깨어난-자유/8072/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/매달리는-기쁨/8071/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/마음을-안는-마음/8067/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/樂-step-요즘엔-스윙댄스를-추고-있습니다/8061/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/산책가자/8059/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/일기를-쓰려는데-아무일도-없었어/8057/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/떠나고-남았다/8055/category/24/display/1/
# 상세 페이지 스크래핑 중: https://indiepub.kr/product/어쩐지-제주에-오고-싶었어/8054/category/24/display/1/
#
# --- 추출된 모든 책 상세 정보 ---
# URL: https://indiepub.kr/product/이러나저러나-불편한-거야-불편한-건/8363/category/24/display/1/
# 제목: 이러나저러나 불편한 거야 불편한 건
# 한 줄 소개: 있는 그대로의 나와 잘 살아가고 싶어 써 내려간 35가지 감정 이야기 <이러나저러나 불편한 거야 불편한 건>
# 요약글: 있는 그대로의 나와 잘 살아가고 싶어 써 내려간 35가지 감정 이야기 <이러나저러나 불편한 거야 불편한 건>‘즐겁다’는 감정을 가장 좋아하지만, 살면서 ‘불안’, ‘후회’, ‘무기력’ 등 나를 불편하게 하는 감정들은 끝없이 찾아와요.때로는 ‘행복’조차도 불편하게 느껴질 때도 있었죠. 불편한 감정에 외면하고 도망쳤지만, 결국 사라지지 않더라고요.이러나저러나 만날 불편한 감정이라면, 제대로 마주해보고 함께 살아가는 법을 배우고 싶었어요. 그렇게 35가지 불편한 감정에 나만의 이름을 붙이게 되었습니다. 이름을 부르면 정이 간다는 말처럼, 불편한 감정을 자주 불러준다면 그 감정들을 잘 마주할지도 모르죠!이 책에는 제가 이름 붙여본 35가지 불편한 감정의 기록, 그리고 함께 써볼 수 있는 감정 기록 코너가 담겨 있어요. 여러분은 요즘 어떤 감정을 자주 마주하나요? 그 감정에 어떤 이름을 붙여주고 싶나요?지금, 우리 함께 불편한 감정을 조금 더 가까이에서 바라보는 연습을 해봐요. <이러나저러나 불편한 거야 불편한 건> 페이지 꼭 붙잡고, 한 장씩 넘겨볼까요?
# --------------------
# URL: https://indiepub.kr/product/불안과-밤-산책/8360/category/24/display/1/
# 제목: 불안과 밤 산책
# 한 줄 소개: 불안을 이겨내기보다, 함께 살아낸 하루들의 기록.불안과 산책하는 마음으로 천천히 걷는 밤.그리고 다시 살아내는 아침.당신의 밤에도 이 책이 작은 숨 쉴 틈이 되기를 바랍니다."이따금 불안한 밤에 천천히 걸어요."
# 요약글: 『어느 날 문득 잘 살고 싶어졌다』 , 『우울의 바깥을 향하며』 이후의 이야기인 두루의 세 번째 산문집입니다.<책 소개>저는 대체로 밤이 되면 불안해집니다.그 불안을 없애려 애쓰기보다,함께 천천히 걸어보고 싶었어요.그런 마음으로 『불안과 밤 산책』이라는 이름을 붙였습니다.이 책은 무언가를 이루지 않아도,느슨하고 조금 부족해도, 그저 하루를 살아낸 당신을 위한조용한 위로의 기록입니다.불안을 애써 무시하지 않고그 불안과 함께 걷는 밤의 산책.당신의 밤에도 이 기록이 작은 숨 쉴 틈이 되기를 바랍니다.“이따금 불안한 밤에 천천히 걸어요.”
# --------------------
# URL: https://indiepub.kr/product/속속들이-독립출판-알고-보니-의존-출판/8357/category/24/display/1/
# 제목: 속속들이 독립출판 알고 보니 의존 출판
# 한 줄 소개: 독립출판 초보자를 위한 안내서. 직접 겪은 모든 과정을, 구체적인 예시를 들어 속속들이, 이해하기 쉽게 설명했다. 주제 잡기부터 원고 마감, 인디자인으로 편집해서 교정보고 인쇄 발주까지! 읽기만 해도 다 만든 기분, 초보를 위한 설명은 초보가 잘한다.
# 요약글: 독립출판이 뭐야?글 쓰고 편집 디자인 직접 해서 책 만들고 판매까지 혼자 다 하는 거지!정말 혼자 다 할 수 있냐고?제가 해보고 이 책에 자세히 써두었습니다.제발 쉽게 설명해줬으면 하는 마음, 판형이고 여백이고 누가 알아서 다 정해줬으면 좋겠는 마음을 기억하고 만들었던 책을 예시로 삼아 자세히 다 적었습니다.초보자를 위한 독립출판 안내서. 글 쓰는 법부터 책 만들어 파는 법까지 전부 알려주는 책.목차 짜는 법, 예산 세우는 법, 마감 지키는 법, 인디자인으로 내지와 표지 만드는 법, 인쇄소에 주문 넣는 법, 독립 서점에 입고하고 북페어 준비까지. 시작부터 끝까지 책 만드는 법 알려드림. 듣기만 해도 책 한 권 만든 기분 들게 해드림. 해볼만하다는 용기를 갖게 해드림.독립출판, 알고 보니 의존 출판인 바로 그 독립출판!저자는 2020년과 2022년에 독립출판 워크숍에서 한 권씩, 2024년에 진짜 진짜 혼자서 독립출판물 두 권을 만들었다.씩씩하게 혼자 쓰고 그리고 엮은 줄 알았는데… 알고 보니 여러 사람에게 의존한 거였다.그 마음에 보답하는 의미로, 누군가는 이 책에 의존하시라고 경험한 독립출판의 전 과정을 속속들이 담았다.초보자도 이해하기 쉽게 설명하고, 만만하게 따라할 수 있는 구체적인 예시를 들었다.속속독을 읽으면 이런 점이 좋습니다.-초보자의 눈높이에 맞춰 쉽게 설명합니다.-<속속독>을 예로 들어 구체적인 수치와 사양을 설명합니다.-그림이 귀엽습니다. 열심히 농사 지어 책으로 수확하는 과정을 그렸습니다.-책 만든 이야기를 따라 읽으면 마치 책을 완성한 듯한 기분이 듭니다. 가상 체험, 대리만족.-이 정도라면 나도 할만하다는 자신감이 생깁니다.
# --------------------
# URL: https://indiepub.kr/product/a-room-of-face-to-face/8356/category/24/display/1/
# 제목: A ROOM OF FACE TO FACE
# 한 줄 소개:
# 요약글: 여러 사람들과 만들어가는 작업은 좋다. 하지만 기획부터 메이크업, 사진, 보정을 한다면 어떨까. 모델들을 집이자 작업실인 공간으로 초대한다. 둘만의 작업은 많은 대화가 오고 갔고 그 결과 다 같이 할 때와는 또 다른 느낌의 작업물을 만들어낸다. 어떤 날엔 오브제까지 만들어 작업 때 쓰곤 했다. 또 다른 날엔 작업 후에 사진을 프린트를 해 그 위에 펄을 뿌리거나 오려 붙이는 아날로그 방식의 작업까지 해가며, 한 장 한 장 채워나간다.내가 추구하는 색은 선명하지 않다. 선명하지 않기에, 피부가 쉽게 비쳐 언뜻 수채화처럼 보인다. 내가 예쁘다고 느끼는 것을 똑같이 느끼게 된다면 되도록 귀로 듣고 싶다.
# --------------------
# URL: https://indiepub.kr/product/savemyself09/8353/category/24/display/1/
# 제목: Savemyself09!
# 한 줄 소개: 8년 동안 쓴 일기장을 책으로 만들었다. 굳이 뜯어보아야 헤아릴 수 있는 마음을 전달하기 위해 독자가 직접 본문을 뜯어 봐야 하는 ‘언컷’으로 구성했고, 하루에도 수십 번씩 가라앉았다 떠오르는 감정의 파동을 자홍색으로 드러냈다.
# 요약글: 열네 살에 이집트, 열일곱 살에 중국을 거쳐 스물다섯 살에 한국으로 돌아왔다. 여자로서, 외국인으로서 사는 삶에 지쳐 나라를 옮겼지만 어느 곳 하나 탐탁지 않았다. 외로움에 허덕이다 일기장을 찾았고 울음을 토했다. 8년 동안 쓴 일기장을 책으로 만들었다. 굳이 뜯어보아야 헤아릴 수 있는 마음을 전달하기 위해 독자가 직접 본문을 뜯어 봐야 하는 ‘언컷’으로 구성했고, 하루에도 수십 번씩 가라앉았다 떠오르는 감정의 파동을 자홍색으로 드러냈다.
# --------------------
# URL: https://indiepub.kr/product/은는이가-당신을-사랑한다/8350/category/24/display/1/
# 제목: (은/는/이/가) 당신을 사랑한다
# 한 줄 소개: 다양한 순간의 사랑을 목격한 그의 시집괄호에 들어가는 은/는/이/가는 그가 마주한 사람들의 이름이 담겨있습니다.그가 사랑을 쫓고 사랑은 시를 쫗는 뜀박질 끝에 마주한 종착지가 바로 이 시집이 되었습니다.
# 요약글: ‘(은/는/이/가) 당신을 사랑한다’는다양한 순간의 사랑을 목격한 그의 이야기가 담겨있습니다.그는 이렇게 말합니다.“ 저는 사랑을 떠올릴 때 누구의 이름이나얼굴이 먼저 떠오르는 걸 보니,사랑의 언어적 원형은 명사에 가까울까 싶습니다.하지만 사랑시를 쓸 땐, 사랑이라는 그 뚜렷함은언제 그랬냐는 듯 시 어귀에, 어딘가에, 아릿하게 묻어 있어종국엔 그저 (은/는/이/가) 정도로 그칠 때가 많습니다.이런방식으로 사랑의 윤곽을 그리다보면사랑은 조사 뒤로 숨어선,지칭이 어려운 대명사처럼 변모해버렸습니다.저는 사랑을 쫓고사랑은 시를 쫓습니다.그렇게 쫓다 도착한 곳이 이 시집이었습니다.”그의 시는 꽤 오랜시간 보따리 속에 숨겨져있었습니다.저는 이 시들을 어서 형체가 있는 책으로 옮겨보자 열렬히 설득했고,그가 드디어 용기를 냈습니다.부디 많은 성원 부탁드립니다.
# --------------------
# URL: https://indiepub.kr/product/반짝이는-나의-계절/8347/category/24/display/1/
# 제목: 반짝이는 나의 계절
# 한 줄 소개: 문장과장면들의 새로운 출판 브랜드 빛그물을 통해 첫 에세이를 펴낸 브런치 작가 볕뉘. 그녀의 에세이에는 어떠한 그늘도 찬란한 계절로 만들어 버리는 다정과 사랑이 담겨 있다.
# 요약글: 그늘을 건너 빛이 쏟아지는 곳으로이별을 딛고 다시 새로운 품으로그리하여 반짝이는 나의 계절이 시작되었다.갑작스럽게 닥쳐온 암 선고소중한 가족과의 이별깊이 사무친 오래전 친구의 죽음....어두운 그늘 속에서 머물 것만 같던 삶은 여행과 글쓰기,한 잔의 커피, 동네 책방에서 만나는 책과 사람들로 반짝이기 시작했다.에세이 『반짝이는 나의 계절』은 브런치 작가로 활동하며 삶에서 마주친 다양한 감정을 세세한 문체로 이야기해 왔던 볕뉘 작가의 첫 번째 챕터이다. 아침이면 신비스러운 물안개와 아름다운 새소리가 반기는 작은 마을에서 어린 시절을 보내고 난 후 도심에서 자신만의 자리를 지키며 열심히 살아가는 동안 갑작스러운 암 선고와 사랑하는 어머니와의 이별을 겪었다. 삶에 드리워진 그늘과 슬픔 속에서도 자신만의 반짝거리는 위로를 발견하고야 마는 볕뉘 작가. 그녀는 이야기한다. 눈물이 쏟아진 자리에서 가장 아름다운 꽃이 피어난다고.커피 한 잔의 위로, 동네 책방에서 마주하는 책과 사람. 일상의 소소한 사랑과 만남을 소중히 하는 그녀의 이야기에는 언제나 깊은 공감과 위로가 자리잡혀 있다.
# --------------------
# URL: https://indiepub.kr/product/기숙사에-재고만이-쌓였습니다/8344/category/24/display/1/
# 제목: 기숙사에 재고만이 쌓였습니다
# 한 줄 소개:
# 요약글: "기숙사에 재고만이 쌓였습니다."처음에는 단순한 농담이었지만, 시간이 흐를수록 한 사람의 삶을 솔직하게 설명하는 문장이 되었습니다. 러시아에서 보낸 시간들, 어설픈 도전과 사소한 실패들, 그리고 그 속에서 건져 올린 조각 같은 이야기들. 이 책은 그 흔적을 기록한 에세이집입니다.낯선 곳에서 길을 잃기도 하고, 예상치 못한 친절에 마음이 움직이기도 하면서 세상을 이해해 가는 과정이 담겨 있습니다. 버스 창문 너머로 스쳐 지나가는 거리 풍경, 손에 쥔 동전의 온기, 우연히 마주친 사람들과의 대화처럼, 거창한 깨달음이 아니라 일상의 작은 순간들을 기록한 책입니다. 이 책이 독자들에게도 삶 속에서 의미 없는 재고처럼 느껴지는 것들 속에서 소중한 무언가를 발견하는 계기가 될 수 있기를 바랍니다.
# --------------------
# URL: https://indiepub.kr/product/아름다운-이-세상은-우리를-시인으로-만들었지/8342/category/24/display/1/
# 제목: 아름다운 이 세상은 우리를 시인으로 만들었지
# 한 줄 소개:
# 요약글: 사랑에 관한 시입니다.사랑을 하고 있고, 사랑에 빠졌던 독자들에게 위로가 되고 공감이 되는 시입니다.
# --------------------
# URL: https://indiepub.kr/product/오늘의문예비평-136호/8340/category/24/display/1/
# 제목: 오늘의문예비평 136호
# 한 줄 소개:
# 요약글: <오늘의 문예비평>은 1991년 봄에 부산에서 창간된 전국 유일의 문예비평 전문지이다. 그 동안 한 호의 결간도 없이 32년(통권 126호)을 계속해온 한국문학비평단의 중요한 매체이다. 문학을 중심으로 한국문학의 이론비평과 실제비평을 병행해오면서 그 영역을 문화비평으로 확대해 왔으며, 이러한 실천은 한국사회의 건강한 비평문화 확산과 지역문화 활성화를 위해 혼신을 다하고 있는 비평전문 계간지이다.
# --------------------
# URL: https://indiepub.kr/product/mtb로-백두대간과-9정맥/8338/category/24/display/1/
# 제목: MTB로 백두대간과 9정맥
# 한 줄 소개: 이 책만큼이나 저자의 땀과 고통이 페이지마다 배어있는 책은 없을 것이다.  길고 힘든 여정을 꼼꼼히 기록한 저자 덕분에 평소 접하기 힘든 책 한 권이 탄생했다. 페이지마다 체력과 정신력의 한계를 끝없이 극복하는 저자 안영환의 의지가 생생히 담겨있다.
# 요약글: 처럼 저자의 땀과 고통이 페이지마다 배어있는 책은 없을 것이다. 대부분의 책은 지식인들의 정신노동의 결과물이기 때문이다. 그래서 땀흘리며 살아가는 사람들의 이야기가 책으로 출판되는 경우는 드물다. 6년 동안의 길고 힘든 여정을 꼼꼼히 기록한 저자 덕분에 독자들이 평소 접하기 힘든 “땀과 인내로 만든 책” 한 권이 탄생했다. 페이지를 넘길 때마다 무거운 산악자전거를 어깨에 메고 가파른 산을 오르는 저자의 모습이 떠오른다. 그러나 이 책은 단순한 종주산행 기록이 아니다. 체력과 정신력의 한계를 끝없이 극복하는 저자 안영환의 의지와 고뇌와 환희가 담겨있는 책이다.은 산을 사랑하는 사람들은 물론이고 자신의 한계에 도전하는 모든 사람들에게 소중한 길잡이가 될 것이다.
# --------------------
# URL: https://indiepub.kr/product/일상의-재발견/8335/category/24/display/1/
# 제목: 일상의 재발견
# 한 줄 소개:
# 요약글: 매달 새로운 사람으로 살 수 있게 돕는 라이프스타일 매거진 《컨셉진》이 건넨 하나의 질문,“당신의 일상을 조금 더 아름답게 만들기 위한 노하우가 있나요?”월간 라이프스타일 매거진 《컨셉진》은 2012년 8월 창간 이래 지금까지, 일상을 아름답게 하는 법에 대해 연구해 왔다. 매달 다양한 주제로 자기만의 가치관에 따라 삶을 살아가는 이들을 만나고, 이들의 이야기를 들으며 평범한 일상도 조금 더 아름답게 만들 수 있다는 확신을 갖게 됐다. 《컨셉진》은 이 확신에 확신을 더하고자 그동안 인터뷰이로 참여해 준 분들께 다시 한번 질문을 건넸다.“당신의 일상을 조금 더 아름답게 만들기 위한 노하우가 있나요?”저마다의 언어로 작성된 144인의 노하우를 읽으며 《컨셉진》은 하나의 공통점을 발견했다. 이들은 모두 ‘내가 좋아하는 나로 살고 있다’는 것을. 다시 말해, 일상이 아름답다는 건 내가 좋아하는 내 모습으로 살고 있다는 것이 아닐까.크리에이티브 디렉터 유병욱, 응원대장 올리부 서은아, 스테이폴리오 대표 장인성, 문구인 김규림, 기록생활자 이승희 등 우리에게 인사이트를 주는 이들이 말하는 144개의 일상을 아름답게 만드는 노하우를 살펴보며 나는 과연 어떤 모습으로 살아가고 있는지 돌아보는 시간이 되길 바란다. 내가 좋아하는 나로 사는 이들의 144개의 답변을 통해 평범한 일상을 조금 더 아름답게 살아가는 방법, 당신만의 일상력을 발견하게 될 것이다.
# --------------------
# URL: https://indiepub.kr/product/잘-될-거야-같은-소리-하네/8334/category/24/display/1/
# 제목: 잘 될 거야 같은 소리 하네
# 한 줄 소개:
# 요약글: 인생을 홀로서기하면서 깨달았던 몇 가지 짧은 글들을 적어 두었다.기댈 곳 없이 자력으로 뭐든지 돌파해야 하는 많은 사람들이 이 책을 보고 문제 해결의 실마리를, 아이디어를, 오기와 독기를 품을 수 있기를 바란다.- 조공을 바치려면 티나는걸로.샴푸 세트 보다는 한우 세트가 기억에 남는다.- 도덕과 합리를 동시에 추구하기는 어렵다.먹고 살만하면 도덕을 따르고, 먹고 살아야 한다면 합리를 따르라.- 이성적으로 행동하면 욕을 먹고 감정적으로 행동하면 일을 그르친다.근데 욕을 먹는게 낫다.
# --------------------
# URL: https://indiepub.kr/product/나는-괴물입니다/8332/category/24/display/1/
# 제목: 나는 괴물입니다
# 한 줄 소개: 어째서 이야기 속 주인공은 늘 영웅이어야 할까요?
# 모두가 알지만 아무도 들여다본 적 없는 괴물, 미노타우로스의 시선으로 다시 보는 신화 이야기.
# 요약글: 어째서 이야기 속의 주인공은늘 영웅이어야 할까요?한번쯤은 그를 본 적 있을 거예요.그림이나 영상 속에서요.황소의 머리에 사람의 몸을 가진 괴물, 미노타우로스 말이예요.하지만 아무도 그의 이야기를 들어본 적은 없어요.왜 어두운 미궁 속에 사는지,왜 사람들을 무섭게 하고, 때로는 잡아먹는지.이 책은 미노타우로스가자신의 목소리로 들려주는 이야기예요.그는 태어나자마자 미궁에 갇혔어요.사람들은 그를 무서워했고, 이름조차 주지 않았어요.사실 미노타우로스는 이름이 아니라 ‘미노스 왕의 황소’라는 뜻이거든요.미노타우로스는 혼자 일어나고, 혼자 놀고, 혼자 잠이 들어요.가끔은 멀리 바다가 보이는 창문 앞에 서서 혼잣말을 해요.‘나는 누구일까?’‘왜 여기 있을까?’『나는 괴물입니다』는 신화를 바탕으로 하지만, 영웅은 등장하지 않아요.동화처럼 보이지만, 마지막엔 정답이 아닌 질문이 남아요.괴물은 태어나는 걸까요? 만들어지는 걸까요?그렇게 만들어진 괴물은 아무런 선택도 할 수 없을까요?그리고… 미노타우로스는어떤 선택을 하게 될까요?
# --------------------
# URL: https://indiepub.kr/product/작은방-한켠-나의-트레킹-가방/8330/category/24/display/1/
# 제목: 작은방 한켠 나의 트레킹 가방
# 한 줄 소개: “걷기의 시작부터 2주간 떠난 산티아고 트레킹” 저자는 두 아이의 엄마로 지난한 육아의 시간을 보내던 어느날, 남편과 서로에게 2주의 여행을 선물하자고 제안한다. 2년 뒤 두고두고 고민하며 떠난 산티아고 트레킹 이야기
# 요약글: “걷기의 시작부터 2주간 떠난 산티아고 트레킹”저자는 두 아이의 엄마로 지난한 육아의 시간을 보내던 어느날, 남편과 서로에게 2주의 여행을 선물하자고 제안한다. 2년 뒤 두고두고 고민하며 떠난 산티아고 트레킹. 스스로를 트레킹하는 여행객이라 부르며 2주의 시간안에 부르고스로 가기 위해 버스도, 택시도 주저없이 탔다. 아이들과 처음으로 떨어져 보내는 2주의 시간과 생장에서 부르고스까지의 여정을 생생히 기록했다.
# --------------------
# URL: https://indiepub.kr/product/conceptzine-vol124/8328/category/24/display/1/
# 제목: CONCEPTZINE vol.124
# 한 줄 소개:
# 요약글: CONCEPTZINE vol.124 - ‘등산’EDITOR’S LETTER3개월 전, 미션캠프에 20대 후반의 디자이너가 입사했습니다. 그녀의 취미는 등산인데요. 매주 혼자서 지방 곳곳으로 등산하러 다닐 정도로 산을 좋아한다고 하더라고요. 그런 그녀의 모습이 신기하기도 하고, 순수하게 궁금한 마음이 들어 등산이 왜 좋은지 물었더니 이런 대답이 돌아왔습니다.“취업 문제, 인간관계 등 정신적으로 힘든 시기를 겪었던 때가 있었는데요. 그때 답답한 마음에 무작정 어디든 떠나고 싶었고 그렇게 한겨울 치악산 등반을 하게 됐어요. 등산 초반에는 고민이 머릿속을 가득 채워서 마음이 무거운데요. 정상을 향해 계속해서 나아가다 보면 체력적으로 힘들어지니까 고민이 점점 밀려나고 한 걸음씩 내딛는 데 집중하게 돼요. 그러다 잠깐 뒤를 돌아보면 저 멀리 작아져 있는 마을과 웅장한 산 능선이 보이는데 뭔가 해냈다는 성취감과 뿌듯함이 느껴지고,처음 가졌던 고민이 생각보다 별거 아니었다는 기분이 들더라고요.”이 말을 들으니, 등산이 너무 궁금해졌습니다. 그래서 미션캠프 팀원들과 함께 그녀를 따라 등산을 가보자고 했죠. 놀랍게도 팀원 대부분이 등산을 종종 하고 있더라고요. 예전에는 어른들이 좋아하는 문화라고 생각했는데…, 제 주변에도 이렇게 등산하는 친구들이 많은 걸 보니 등산이 MZ들에게 힙한 문화라는 게 그제야 실감났습니다.4월 19일, 시간이 맞는 팀원들과 함께 관악산을 올랐습니다. 어릴 적 동네 뒷산에 있는 약수터에 다녀오던 걸 제외하면 제대로 하는 등산은 처음이라, 저는 마냥 설레는 마음이었습니다. 무엇보다 팀원들과 함께 등산한다는 게 신이 나 한껏 들떠있었죠. 하지만 산을 오를수록 점점 웃음기가 사라지고 말수가 줄었습니다. 첫 등산인 제 수준에 맞춰 가장 쉬운 코스를 골랐다던데…, 이게 쉬운 코스가 맞는지, 그리고 얼마나 남았는지 재차 질문했습니다.평소 운동량이 없던 저는 중간에 머리가 ‘핑-’ 하고 돌면서 현기증을 느끼기도 했습니다. 팀원들이 제 속도에 맞춰 중간중간 멈추며 제 컨디션을 살펴줬고요. 체감상 끝없는 계단을 오르다 결국, 3분의 2 지점에 이르러서는 제 입에서 이 말이 터져 나왔습니다.“아 XX, 이 힘든 것도 했는데 못 할 게 뭐야!”정말 그랬습니다. 몸이 힘드니 머릿속 고민이 자연스레 사라졌고, 이 힘든 것도 참고 해냈는데, 못 할 게 뭐가 있을까 싶더라고요. 비로소 다들 왜 그렇게 등산이 좋다고 하는지 알게 됐고, 다른 사람들에게 추천할 만한 문화라는 확신이 들어 바로 다음 날 팀원들에게 제안했습니다. 우리 다음 호 주제를 ‘등산’으로 하자고. 그리고 독자분들에게 이 말을 꼭 전하고 싶었습니다.“고민이 있을 땐 산에 한번 가보세요!”편집장 김경희
# --------------------
# URL: https://indiepub.kr/product/부라보-마이-라이프/8326/category/24/display/1/
# 제목: 부라보 마이 라이프
# 한 줄 소개: 모두의 삶에 보내는 응원과 찬사의 메세지!부라보 마이 라이프! 부라보 유어 라이프! 그림책과 컬러링북으로 만나는 공감과 위로의 시간!
# 요약글: 강원도 탄광마을에서 평생을 살아 온 이들의 이야기로부터 시작된 그림책입니다.  그들의 기억 속에 남아있는 그리운 것들과 마음 속에 새겨져 있는 사랑스러운 것들을 그림으로 그렸습니다. 눈을 반짝이며 즐겁게 떠올리는 순간의 말들을 그 분들의 입말을 살려 글로 적었습니다. 그림마다 이야기들이 숨은그림찾기처럼 조각조각 숨어있답니다. 그리고 원화에서 골라 낸 간결한 선의 컬러링북을 통해 한번 더 그림책 속으로 풍덩 빠져볼 수 있습니다.세대를 관통하는 삶에 대한 찬사와 응원의 메세지를 그림책과 컬러링북 세트로 만나세요!
# --------------------
# URL: https://indiepub.kr/product/아날로그/8323/category/24/display/1/
# 제목: 아날로그
# 한 줄 소개: 핸드폰 같지만 책입니다. 핸드폰을 절대 만질 수 없는 '아날로그 남자'와핸드폰 없이는 살아갈 수 없는 '디지털 시대 여자'의 엉뚱 발랄한 업무와 사랑을 그린 미니 소설 '아날로그'
# 요약글: 미니 소설 『아날로그』는스마트폰이 세상의 숨결처럼 깊숙이 스며든 지금,스마트폰을 절대 만질 수 없는 '아날로그 남자'와스마트폰 없이는 살아갈 수 없는 '디지털 시대 여자'의유쾌하고 톡톡 튀는 로맨스를 그립니다.소설과 블로그 식 글이 교차하며 펼쳐지는 신선한 구성스마트폰 화면 그대로를 담아낸 기발한 책 디자인까지.잠시 스마트폰을 내려놓고손끝이 아닌 마음으로 터치하는신 개념 아날로그 폰 북, 아날로그를 만나보세요.
# --------------------
# URL: https://indiepub.kr/product/마음챙김-플라워-힐링북/8320/category/24/display/1/
# 제목: 마음챙김 플라워 힐링북
# 한 줄 소개: 이 책은 적극적이고 꾸준한 마음챙김을 돕고자 72개의 플라워를 삽입하여 힐링도 하고 색칠도 할 수 있도록, 또한, 내 마음을 솔직하게 적어 볼 수 있도록 구성하였습니다. ‘마음챙김 플라워 힐링북’으로 나의 심리 근육을 단단하게 만들어 보시길 바랍
# 요약글: 오늘 당신은 어떤가요? 행복한가요? 힘든가요? 자신의 마음을 먼저 살펴보세요. 내 마음이 어떤지, 내가 어떤 생각으로 힘들어하는지, 자신과의 대화를 통해 내면의 나를 만나 보세요.이 책을 통해 나를 알아가는 시간을 갖기를 바랍니다. 이런 알아차림을 통해 나를 사랑해 주고, 안아주고, 보듬어 주세요.이 책은 나 자신을 솔직하게 만나볼 수 있도록 구성된 셀프 힐링북입니다.
# --------------------
# URL: https://indiepub.kr/product/울지마/8318/category/24/display/1/
# 제목: 울지마
# 한 줄 소개: 손끝에서 펼쳐지는 조용한 위로, 슬로우 플립북 <울지마>
# 완전한 어둠 속에서는 미약한 빛이라도 존재감을 드러내듯,
# 절망의 순간, 자신도 몰랐던 힘을 마주할지 몰라요.
# 2024 현대어린이책미술관 UI 출판지원작
# 2024 dPICTUS 미출간그림책 선정
# 요약글: ‘상실과 절망 속에서 내면의 빛을 발견하는 순간’완전한 어둠 속에서는 아주 미약한 빛이라도 그 존재감을 갖듯이, 절망의 순간 속에서 자신도 몰랐던 힘을 발견할 수 있는지 모른다. 제목은 ‘울지 마’이지만, ‘울어도 된다’고 다독인다. 결심하지 않아도, 힘을 내지 않아도 우리 안에는  스스로를 회복할 수 있는 빛이 있다.‘손끝에서 펼쳐지는 조용한 위로’<울지 마>는 글 없는 그림책이자 플립북이다. 플립북 형식을 통해서 번지는 울음의 이미지를 속도감 있게 담아내면서도, 그 속도와 이미지 간의 미묘한 어긋남이 독특한 감각을 만들어낸다. 책장을 넘기며 멈추고 싶은 순간들을 지나, 마침내 도달하는 울음 이후의 개운함이 독자를 위로하며, 처음부터 다시 천천히 넘겨보게한다.2024년 현대어린이책미술관이 주최한 제4회 언-프린티드 아이디어 전시 및 출판 지원작이며, 같은 해 dPICTUS 미출간그림책 쇼케이스에 선정되어 국내 작품 중 최다 득표를 기록했다.‘물 밑의 영혼은 다치지 않아.물 위로 폭풍이 몰아치고,파도가 뒤집히고,하늘이 불타올라도물 밑의 영혼은 더해지지도 덜해지지도 않아.’_작가의 말 중에서<울지 마>는 총 100여 장의 수작업 이미지를 이용해 전통적인 셀 애니메이션 방식으로 제작되었다.동양화 물감의 친수성과 유연한 확장성을 통해 책장을 넘기면 종이가 눈물에 젖어들어가는 것 같은 이미지가 연출된다. 흥미롭고 짧은 디지털 영상이 넘쳐나는 시대에, <울지 마>는 아날로그 감각으로 새로운 매력을 선사한다. 페이지를 넘기는 데는 몇 초밖에 걸리지 않지만, 이 말없는 플립북은 마음과 손끝에 오래도록 잔상이 남을 것이다.'한정판 아트북'초판 400부는 모두 수기 넘버링된 한정본으로, 현대어린이책미술관의 제작 지원을 받아 아트북 형태로 출간되었다. 책의 배면 전체가 깊은 파란색으로 인쇄되어 마치 푸른 바다 조각을 손에 쥔 인상을 가진다.
# --------------------
# URL: https://indiepub.kr/product/small-brand-high-value/8316/category/24/display/1/
# 제목: Small Brand, High value
# 한 줄 소개: 단 한 번이라도 내 브랜드를 꿈꿔본 사람을 위한 책이자 실제 사례로 이해하는 스몰 브랜드 지침서. 2015년부터 발행 중인 브랜딩 뉴스레터 ‘Small Brand, High Value’에 소개된 스몰 브랜드 중 30가지 이야기를 통해 영감을 나눈다.
# 요약글: 요즘 특히 많은 사람들이 자기만의 브랜드를 꿈꾼다. 경기 불황으로 인해 언제 퇴사하게 될지 모른다는 불안감, 코로나 팬데믹 등의 영향으로 더욱 주목받게 된 N잡러 라이프, 일하는 방법의 다양한 변화 등이 그 원인이다. 그래서일까? 이젠 브랜딩 업계의 종사자가 아닌 사람들도 브랜딩을 알아야 하는 시대가 되었다. 하지만 전문적 영역인 브랜딩을 이해하는 것은 쉽지 않은 일이다. 또한 브랜딩 이론서나 노하우를 알려주는 콘텐츠 등의 정보를 직접 활용하는 것도 어렵다. 이 책은 그러한 간극에서 고민 중인 사람들에게 영감과 도움을 주고자 발간되었다.자영업자, 브랜드 대표, 1인 사업가, 예비 창업자, N잡러 등 누구나 이해하기 쉽고 재미있게 브랜딩을 소개하는 이 책은 30가지 가치 있는 스몰 브랜드 사례로 구성되었다.저자가 2015년부터 꾸준히 운영 중인 브랜딩 뉴스레터 ‘Small Brand, High Value’에 소개되었던 300여 가지 스몰 브랜드들 중, 여전히 가치 있는 30가지를 꼽아 현 상황에 맞춰 이야기한다. 특히 기존의 다른 도서나 콘텐츠 등에 소개되지 않아, 여전히 숨은 보석 같은 스몰 브랜드의 이야기와 히스토리가 담겨 있어 더욱 소장 가치가 높다.무언가를 하고자 할 때, 때론 다른 사람들이 어떻게 하는지 참고하는 것은 매우 큰 도움이 된다. 작곡가를 꿈꾸는 사람에게 화성학 공부만큼 다른 뮤지션의 음악을 많이 듣는 것 또한 좋은 경험이 되는 것처럼 말이다. 브랜딩도 그렇지 않을까? 작지만 자기만의 이야기를 무기로 가치 있는 브랜드를 만들어가는 그들을 주목해 보자. 30개의 영감이 나의, 또는 우리의 브랜드에 어떠한 영향을 줄게 될지 기대하며.
# --------------------
# URL: https://indiepub.kr/product/일시-정지-후-재생/8313/category/24/display/1/
# 제목: 일시 정지 후 재생
# 한 줄 소개: 일시 정지된 삶에서 다시 움직이게 한 기록.이 책이 당신의 하루에 쉼표이자 재생의 힘이 되길 바랍니다.
# 요약글: 2020년 6월, 섬유근육통이라는 통증 질환을 진단받은 후 제 삶은 완전히 달라졌습니다.버티고 또 버티며 겪어낸 시간을 기록한 이 책은, 어려운 시간 속에서도 희망을 잃지 않고 살아가려는 마음을 담고 있습니다.‘너는 혼자가 아니야, 나도 이렇게 살아내고 있어.’라는 마음으로, 현재의 삶을 묵묵히 견뎌내고 있는 모든 이들에게 따뜻한 위로와 공감을 전하고자 합니다.어려운 시간 속에서도 앞으로 나아갈 수 있는 용기를 전하며, 누구나 읽고 나면 마음 한쪽에 남는 무언가가 있을 그런 책이 되길 바랍니다.
# --------------------
# URL: https://indiepub.kr/product/엉망진창인채로-40대-오히려-좋아/8310/category/24/display/1/
# 제목: 엉망진창인채로 40대, 오히려 좋아
# 한 줄 소개: ‘나는 왜 이모양일까, 커서 뭐가 되려고 이럴까’40대가 되어서도 매일 이 생각을 하게 될 줄은 몰랐다. 하지만 내가 경험했던 것, 경험을 통해 알게 된 것들. 그리고 그 과정을 잘 지나온 나를 믿기에 엉망진창인 채로 40대가 되어도 오히려 좋다
# 요약글: 사랑하는 첫 딸의 이름을 순한글로 짓고 싶다는 바람으로 국어사전을 열심히 찾아가며 고르고 골라 선택한 이름이 “은하수”라는 뜻을 가진 “미리내”였고, 아빠 성의 “양”을 붙이고 부르기 쉽게 “미리”라고 지어 붙인 귀한 이름이 하필이면 양,미.리(梁미리)님 되시겠다.생선 양미리와 이름이 같은 작가는 인생의 시작부터 엉망진창이었다. 그래도 살다 보면 나아지겠거니 했는데 엉망진창인 채로 40대를 맞이하고 만 ENFP의 우당탕탕 생존기이자 이런 나라도 사랑하고자 애쓰는 눈물기이다.2장은 나 하나도 제대로 간수하지 못하는 작가가 자기와 똑닮은 딸과의 대화를 담았다. 아이의 시선으로 엄마와 나눈 대화는 생각지도 못한 삶의 정답을 알려준다.작가가 엉망진창이라고 얘기하는 삶의 이야기라 읽는 내내 입가에 웃음이 끊이지 않지만 결코 가볍지만은 않은 이야기라 한 번 읽기 시작한 책을 쉽게 놓을 수 없다.아직은 어른이 되기에 멀었다고, 이런 내가 40대가 되는 것이 두려운 사람들에게 엉망진창인 채로 40대를 맞이해도 오히려 좋다고 얘기해주는 이 책을 권하고 싶다.
# --------------------
# URL: https://indiepub.kr/product/외계행성-다방유랑기/8308/category/24/display/1/
# 제목: 외계행성 다방유랑기
# 한 줄 소개:
# 요약글: 28세기의 미래, 인간과 다양한 외계 종족이 어울려 살아가는 행성 '칸데리'. 주인공 '선희'는 어느 날 친구 '마리소'의 손에 이끌려 우연히 외계 디저트를 접하게 된 것을 계기로 여러 외계 종족들의 디저트들을 찾아다니게 되는데...?'선희', '마리소', 그리고 '카알' 세 명의 친구들이 함께 펼치는 일상 속 디저트 여행기.
# --------------------
# URL: https://indiepub.kr/product/즉흥-연주를-위한-실전-코드-사전/8307/category/24/display/1/
# 제목: 즉흥 연주를 위한 실전 코드 사전
# 한 줄 소개: 코드 원리부터 파워코드·잽잽이 주법까지 수록! 손 모양·구성음까지 친절하게 담은 실전형 코드북. 초보자부터 고급 연주자에게 모두 필요한 코드 정보를 담은 책
# 요약글: 기타 연주에서 가장 핵심이 되는 요소는 단연 코드입니다. 이 책은 코드의 원리를 이해하고, 한 가지 코드를 다양한 폼에서 응용할 수 있도록 구성된 실전형 코드북입니다. 파워 코드, 트라이어드 코드, 세븐스 코드, 특수 코드까지 각 키별로 정리하고, 코드마다 손 모양과 구성음을 함께 수록하여 초보자도 쉽게 접근할 수 있도록 만들었습니다. 또한, 오부리 교재에서 다루는 **필수 주법(파워코드 주법, 잽잽이 주법)**을 부록으로 담아, 코드와 리듬을 함께 연습할 수 있도록 도왔습니다.복잡하고 어려운 코드도 이 책 한 권이면 실전에 바로 활용할 수 있습니다.기타를 즐겁게 배우고 싶은 모든 분께 추천드립니다.
# --------------------
# URL: https://indiepub.kr/product/기타-연습-가이드북/8305/category/24/display/1/
# 제목: 기타 연습 가이드북
# 한 줄 소개: 기타 치기 싫을 때 읽는 책. 기타 경력 30년, 구독자 20만 명이 넘는 기타 유튜버로 활동 중인 오부리킴의 노하우를 담은 책이다. 매일 매일 그의 가이드를 따라가다 보면 어느새 기타 실력이 훌쩍 성장한 자신을 발견하게 될 것이다.
# 요약글: 기타 경력 30년, 구독자 20만 명이 넘는 기타 유튜버 오부리킴이 제시하는 기타 연습 노하우를 담은 책이다. 기타를 잘 치기 위한 마인드와 경험, 기본 코드와 주법 훈련, 연습 루틴을 위한 365일 연습 일지가 수록되어 있다.1부는 기타와 함께한 저자의 삶의 이야기, 2부는 기타 연습에 필요한 마음가짐, 3부는 기억해 두면 유익한 실전 노하우들을 담았다. 또한 2부와 3부에는 연습일지가 포함되어 있어 기타를 꾸준히 연습하고자 하는 이들에게 실질적인 도움이 된다.
# --------------------
# URL: https://indiepub.kr/product/조각난-기억-사랑으로-남다/8302/category/24/display/1/
# 제목: 조각난 기억, 사랑으로 남다
# 한 줄 소개: 조각난 기억, 사랑으로 남다
# 요약글: 『조각난 기억, 사랑으로 남다』은 치매 어르신들과 그 가족들이 겪는 슬픔과 아픔 그리고 그 속에서도 피어나는 희망의 빛을 섬세하게 담아낸 시집입니다. 최정숙 작가는 오랜 사회복지 현장에서 치매 어르신들과 함께하며 쌓은 깊은 경험과 공감의 눈길로 잃어버린 기억의 파편들 사이에 숨겨진 인간애와 삶의 소중함을 시어로 풀어냅니다. 이 책은 단순히 치매로 인한 기억 상실과 고통을 다루는 데 그치지 않습니다. 치매라는 어려운 현실 속에서도 어르신들이 보여주는 천진난만한 미소 때로는 눈물로 드러나는 슬픔 그리고 잊혀진 과거 속에 피어나는 작은 기쁨들을 조명합니다. 작가는 마치 한 조각의 퍼즐을 맞추듯 어르신들이 걸어온 긴 세월의 흔적과 그들이 남긴 소중한 순간들을 세밀하게 포착하고 또한 각 시마다 시노트가 적혀있어 독자로 하여금 그들의 이야기에 깊이 공감하도록 이끕니다.책 속에는 치매 어르신들의 잔잔하지만도 애절한 이야기가 담겨 있습니다. 이들은 자신들의 기억이 서서히 흐려지는 현실 앞에서도, 한때 반짝이던 청춘의 열정과 가족에 대한 애정을 잃지 않고 살아왔습니다. 작가는 그러한 순간들을 노래하며, 잃어버린 기억 속에서도 여전히 반짝이는 인간의 본질과 사랑의 가치를 되새기게 만듭니다. 이는 단지 한 세대의 이야기가 아니라, 우리 모두가 언젠가 마주할 삶의 한 단면임을 상기시켜 줍니다. 또한, 『조각난 기억, 사랑으로 남다』은 치매 어르신들을 바라보는 사회의 시각과 우리 각자가 지녀야 할 따뜻한 관심, 그리고 돌봄의 자세에 대해 생각해보게 만듭니다. 치매라는 질병이 단순한 신체적 문제가 아니라 기억과 정체성의 소중함 그리고 세대를 잇는 소통의 가치를 일깨워 주는 중요한 주제임을 작가는 보여줍니다. 이 시집은 치매 어르신들을 위한 사회복지 현장의 현실을 담담히 풀어내면서도 동시에 그 안에서 피어나는 희망과 위로의 메시지를 강하게 전달합니다.독자는 이 시집을 통해 치매로 인해 흩어진 기억의 조각들을 다시 하나로 엮어가는 작업에 동참하게 됩니다. 작가의 따뜻한 시선과 섬세한 언어는 잊혀진 추억들이 단순한 아픔이 아닌 한 인간의 삶과 역사를 품은 보석임을 깨닫게 합니다. 『조각난 기억, 사랑으로 남다』은 우리 모두가 살아가며 마주치는 시간의 무상함 속에서도 인간관계와 기억이 주는 위로와 소중함을 다시 한번 생각해 보게 하는 작품입니다.
# --------------------
# URL: https://indiepub.kr/product/사탄탱고-벨라-타르에-들어가기-앞서/8298/category/24/display/1/
# 제목: 사탄탱고: 벨라 타르에 들어가기 앞서
# 한 줄 소개: 이번 책은 〈사탄탱고〉 상영을 기념하여, 벨라 타르의 생애와 작품을 다각도로 조망한다. 특히 벨라 타르의 초기 작품과 〈사탄탱고〉 분석을 비롯해, 벨라 타르의 인터뷰를 통해 그의 영화적 철학과 현대 영화계에 대한 통찰을 엿볼 수 있다.
# 요약글: 헝가리의 영화 감독 '벨라 타르'는 1978년 단편 〈호텔 마그네지트〉를 시작으로 30여년 간 총 9 편의 장편 영화를 연출했다. 그리고 그는 2011년 〈토리노의 말〉을 끝으로 은퇴를 선언했다. 그의 이름은 오랜 시간 시네필들 사이에서 회자 되었다. 2008년 제 9회 전주국제영화제에서는 그의 회고전을 진행하며 벨라 타르가 직접 한국을 방문하기도 했다. 그리고 벨라 타르에 관한 담화의 중심에는 언제나 그의 매그넘 오퍼스(Magnum Opus), 〈사탄탱고〉가 있었다.하지만 그 명성에 비해 벨라 타르는 한국의 관객들이 쉽게 접근하기 어려운 감독이었다. 그의 작품 대부분이 20세기에 발표되었을 뿐만 아니라, 7시간 30분에 달하는 영화 〈사탄탱고〉는 그 자체로 오르기 어려운 나무와 같았기 때문이다.2025년 3월 '시네마토그래프' 주관으로 예술영화관 '아트하우스 모모'에서 〈사탄탱고〉 상영이 예정되어 있다. 이를 기념하며, 그리고 이 영화적 사건에 참여할 많은 관객들을 위하여 〈사탄탱고: 벨라 타르에 들어가기 앞서〉가 발간된다. 이 책은 벨라 타르의 생애와 커리어를 망라한다. 국내외 영화 연구가들이 기술한 벨라 타르의 초기작, 그리고 〈사탄탱고〉 분석을 포함하며, 벨라 타르 인터뷰를 통해 자신의 필모그래피와 오늘날 영화계를 바라보는 그의 생각을 엿볼 수 있다. 벨라 타르 영화학교 출신의 일본 다큐멘터리스트, '오다 카오리' 감독의 회상은 거장에 대한 경외와 친근감을 동시에 전달한다.
# --------------------
# URL: https://indiepub.kr/product/two-of-a-kind/8297/category/24/display/1/
# 제목: Two Of A Kind
# 한 줄 소개: 강릉 주변을 여행하면서 본 흥미로운 시선들 그리고 각 사진속에서 발견한 빛을 책에 담다.
# 요약글: 이 책은 강원도 강릉에서 총 두번의 여행 2023년 11월에 사흘 동안의 여행 그리고 2025년 2월에 하루 동안의 여행을 통해 기록한 사진을 엮어서 만들게 되었습니다. 강릉 주변을 여행하면서 본 흥미로운 시선들 그리고 각 사진들이 서로 주고받는 대화를 담았습니다.
# --------------------
# URL: https://indiepub.kr/product/퇴사-후-치앙마이/8296/category/24/display/1/
# 제목: 퇴사 후, 치앙마이
# 한 줄 소개: 퇴사 후 지친 몸과 마음을 치유하기 위해 떠난 치앙마이에서의 기록을 사진과 함께 엮은 여행 산문집
# 요약글: 『퇴사 후, 치앙마이』는 퇴사 후 지친 몸과 마음을 치유하기 위해 떠난 치앙마이에서의 기록을 사진과 함께 담아낸 여행 산문집이다. 따뜻한 날씨보다 더 따뜻한 사람들을 만나고, 공간에 머물며 오감으로 느낀 감각들을 마흔두 편의 글로 엮었다.따뜻한 날씨, 심드렁한 고양이, 공원에서 요가를 즐기는 사람들. 자연을 가까이 두고 여유를 누릴 수 있는 도시. 치앙마이는 멈춤과 여백의 아름다움을 알려준 곳이다.여행을 마치고 손바닥만 한 노트에 적은 글을 정리하며, 여행 그 자체보다 여행 중 품었던 감정과 생각을 되돌아보는 시간을 갖는 것이 여행만큼 중요하다는 깨달음과 마주할 수 있었다. 나 자신을 마주하는 데 기록만큼 좋은 도구가 있을까.이 책을 읽는 순간만큼은 아무런 걱정 없이 평온하시길 바라며, 일상에 지친 분들께 작은 위로와 쉼으로 닿기를 바란다.
# --------------------
# URL: https://indiepub.kr/product/기억나무/8294/category/24/display/1/
# 제목: 기억나무
# 한 줄 소개: 코넬리아드랑게증후군이라는 희귀질환을 갖고 태어난 창성이. 2024년 5월 5일에 16년의 짧은 생을 마감하고 하늘나라로 떠났지만 그가 남긴 미소와 진실한 사랑은 우리의 기억에 영원토록 살아있을 겁니다. 그를 그리는 아름다운 치유의 숲으로 초대합니다.
# 요약글: 창성이는 코넬리아드랑게증후군이라는 선천성희귀질환을 갖고 태어났습니다. 열여섯 살이 되어도 다섯 살 정도의 작은 몸집을 가진 창성이에게는 별명이 여러 개 있었습니다. 어린 왕자, 쪼끔이, 뿡뿡이, 피터팬 등. 그중 ‘피터팬’이라는 별명은 나이를 먹어도 늘 아이 같은 모습으로 있었기 때문이기도 하지만 아빠를 열렬히 좋아해서 붙여진 것이기도 합니다. 아빠의 영어 이름은 피터이고 창성이는 아빠의 진정한 팬이었으니까요. 창성이는 2024년 5월 5일 어린이날에 16년간 진심으로 사랑했던 가족의 곁을 떠나 하늘나라로 갔습니다. 그가 하늘나라로 가기 전 마지막까지 보여준 아빠에 대한 깊은 사랑, 그를 그리워하는 가족과 지인들의 이야기를 이 책에 담았습니다. 죽음이 사랑의 끝이 아니라 또 다른 시작임을, 진실한 사랑은 영원한 것임을 『기억나무』를 통해 다시 한번 되새기게 됩니다.
# --------------------
# URL: https://indiepub.kr/product/새벽-죽음-연습/8291/category/24/display/1/
# 제목: 새벽 죽음 연습
# 한 줄 소개: 작가 이한이 전개하는 시집 시리즈 <시야문집>의 두 번째 작품, 『새벽 죽음 연습』은 삶의 최하단에서 모든 것을 내려놓은 후에야 가벼워질 수 있었던 이야기입니다. 책을 읽고 누군가 살아볼 용기를 얻는다면, 그것으로 이 책은 소임을 다했습니다.
# 요약글: 『새벽 죽음 연습』은 어둡고 가라앉는 분위기로 흐르는 시집입니다.다소 자극적인 제목 때문에 '자살 권장 도서'라는 오해를 받을지도 모르겠습니다. 하지만 마지막까지 읽었을 땐 오히려 반대라고 느낄 수도 있겠습니다. 실제로 책의 콘셉트는 '죽음'보다 '연습'에 초점이 맞춰져 있습니다.우리는 무엇인가 잘하고 싶을 때 연습을 합니다.사람들은 잘 살기 위해서 입시, 취직, 재테크, 품위와 교양 등에 지나치게 몰두하며, 좋은 삶의 표본에 가까워지려고 합니다. 표본으로부터 계속 멀어지는 저는, 여전히 잘 사는 것이 무엇인지 모르겠습니다. 그러나 죽음의 충동이 몸 안에서 꿈틀대던 시절 끝내 알게 된 것은, 잘 사는 것만큼이나 잘 죽는 것이 중요하다는 사실입니다.잘 죽는다는 것은 '준비된 죽음'을 말합니다.그것은 죽음을 인식하는 것에서부터 출발합니다. 삶이 과정이라면 죽음은 결과이자 인간 여정의 최종 목적지입니다. 목적지를 알아보지 않고 비행기부터 오르는 여행객은 없듯이, 죽음을 떠올리고 구체화할수록 앞에 펼쳐진 길은 끊어지지 않고 더욱 견고해집니다. 어둠 속에서 빛이 선명해지듯 삶에 대한 의지는 점차 타오를 것입니다."은하수는 밑바닥에서 가장 깊다"『새벽 죽음 연습』은 삶의 최하단에서 모든 것을 내려놓은 후에야 가벼워질 수 있었던 이야기입니다. 책에 실린 52편의 시는 죽음의 메타포를 중심으로 독자를 감상의 소용돌이로 데려갑니다. 그 속에서의 숱한 몸부림은 삶을 돌아보는 귀중한 시간이 되어줄 것입니다.'죽겠다', '죽고 싶다' 같은 말이 대지 위로 범람하는 세계, 새벽마다 죽음이 가까워지는 사람들.현대인에게 죽음은 쉽지만 어려운 도피처 같다고 씁니다. 이 책은 아무래도 삶과 죽음의 경계에 서 있는 이들 손에 자주 쥐어질 것 같습니다. 그들에게 '죽지마'란 위로 대신 '정말 지금이 죽을 적기인가'란 자문이 남길 바라며, 각자의 삶을 응원하는 마음입니다.
# --------------------
# URL: https://indiepub.kr/product/뇌경색-환자의-좌충우돌-1인-출판사-창업기/8288/category/24/display/1/
# 제목: 뇌경색 환자의 좌충우돌 1인 출판사 창업기
# 한 줄 소개: 뇌경색을 딛고 홀로 선 저자의 출판사 창업기! 좌충우돌 속에서도 피어난 열정과 실전 노하우를 담은 생생한 이야기.
# 요약글: 삶이 예기치 못한 순간에 찾아온 뇌경색으로 무너졌을 때, 저자는 ‘새로운 출발’을 위해 1인 출판사를 열기로 결심했습니다. 직접 책을 만들고 세상에 내놓는 일은 두렵기도 했지만, 자신의 이야기와 작가의 이야기를 전하며 누군가에게 힘이 될 수 있다는 믿음이 용기를 주었습니다. 그리고 마침내, 여러 시행착오 끝에 탄생한 이 책은 ‘나도 출판을 할 수 있을까?’라는 막연한 물음에 구체적이고 현실적인 해답을 전해줍니다.『뇌경색환자의 좌충우돌 1인 출판사 창업기』는 출판을 전혀 해본 적이 없는 초보도 손쉽게 따라 할 수 있는 구체적인 방법들을 담았습니다. 1인 출판사를 시작하기 전 반드시 알아야 할 것들, 출판사 법적 절차와 인쇄•유통 노하우, 작가 발굴과 편집 디자인 실무, 나아가 SNS 마케팅을 통한 독자와의 소통법까지. 이 책 한 권이면 1인 출판사를 운영하는 데 필요한 핵심 지식을 한눈에 정리할 수 있습니다. 무엇보다 뇌경색을 극복한 뒤 저자가 다시 삶을 일으켜 세운 과정이 고스란히 녹아 있어, 단순히 ‘어떻게 출판을 할 것인가?’라는 기술적인 면을 넘어 ‘왜 출판을 하고, 어떤 의미를 전해야 하는가?’라는 질문까지 함께 생각해볼 수 있습니다. 한 권의 책을 통해 세상과 연결되고 싶은 예비 출판사 대표, 자비 출판을 꿈꾸는 작가 지망생, ‘나만의 이야기를 누군가에게 전하고 싶다’는 모든 이들에게 소중한 동력이 될 것입니다.이 책을 통해 독자들은 현실적인 조언과 함께 출판 과정 전반을 체계적으로 이해할 수 있고, 저자의 진솔한 경험담을 통해 어떤 어려움 앞에서도 용기를 낼 수 있는 힘을 얻을 수 있습니다. 한 걸음씩 내디디며 1인 출판사로 성장해 나가고자 하는 이들에게, 이 책은 든든한 길잡이가 되어 줄 것입니다.
# --------------------
# URL: https://indiepub.kr/product/로컬-매거진-인천-스펙타클spectacle-05-술술-읽히는-인천의-술/8286/category/24/display/1/
# 제목: 로컬 매거진 인천 스펙타클(spectacle) : 05 술술 읽히는 인천의 술
# 한 줄 소개: 오늘, 어디서 누구와 한 잔 하고 싶으세요? 막걸리부터 위스키까지, 양조장부터 뜨개 모임이 열리는 술집까지. 인천에서만 가능한 술의 풍경과, 그 술을 둘러싼 사람들의 이야기를 담았습니다.
# 요약글: 전통주부터 인천공항 세관 주류공매까지, 인천 술 문화의 스펙트럼을 한 권에 담다계란초, 닭알탕, 물텀벙—인천에서만 맛볼 수 있는 독특한 안주 문화부터, 지역을 대표하는 전통주 양조장 이야기, 인천공항 세관 주류 공매 도전기까지. 단순히 술을 마시는 경험을 넘어 인천에서만 가능한 술의 장면들을 섬세하게 포착했다. 한 병의 술이 어떤 시간에서, 어떤 장소에서 만들어지고 소비되는지를 따라가다 보면, 그 도시가 지닌 맛의 역사와 공간의 맥락이 선명히 떠오릅니다. 이번 호는 '술을 안주 삼아 도시를 마신다'는 말이 딱 어울린다.'부어라 마셔라' 대신, 내 취향이 허락한 술자리요즘 술은 그냥 마시는 게 아니라 어디서 누구와, 어떤 방식으로 마시는지가 중요해졌다. 낮에는 직장인으로 일하고 밤에는 술집을 운영하는 투잡러 사장들, 뜨개질 모임과 디제잉 파티가 열리는 동네 술집 등, 술을 둘러싼 삶의 장면들이 책에 가득하다. 단순히 ‘마시는 술’이 아닌 ‘머무는 술자리’를 이야기하며, 삶과 취향이 녹아든 공간들을 소개한다. 특히 주류 소비자들의 취향이 세분화되며, 술 역시 ‘개인의 라이프스타일’로 자리잡고 있는 흐름을 로컬의 관점에서 세심하게 포착했다는 점에서 의미가 깊다. 이번 호는 마시고, 일하고, 사는 곳이 하나로 연결되는 로컬의 일상을 술이라는 키워드로 섬세하게 풀어낸다.‘부어라 마셔라’로 대변되던 술 문화는 점점 저마다의 속도와 취향을 반영하는 방향으로 변하고 있다. 한 잔의 술을 누구와, 어떤 공간에서, 어떤 방식으로 나누는지가 중요해진 지금, <인천 스펙타클> 5호 ‘술술 읽히는 인천의 술’은 도시와 사람, 취향이 얽힌 술의 장면들을 로컬의 시선으로 세심하게 기록했다. 전국의 애주가에게는 인천으로 발걸음을 옮길 만한 하나의 좋은 핑계가, 인천의 이웃들에겐 서울 막차 걱정 없이 집 근처에서 즐기는 느긋한 막잔의 기쁨이 되었으면 한다. 이번 호를 통해 술이라는 키워드를 매개로, 도시를 읽는 새로운 방식을 경험해보길 권한다.
# --------------------
# URL: https://indiepub.kr/product/넘어졌던-자리에서-다시-걸을-수-있다면-정말-괜찮습니다/8279/category/24/display/1/
# 제목: 넘어졌던 자리에서 다시 걸을 수 있다면 정말 괜찮습니다
# 한 줄 소개: 넘어지는 건 누구에게나 일어나는 일이다. 하지만 다시 걷겠다는 다짐은 누구나 쉽게 할 수 없는 선택이다. 이 책은, 당신을 믿고 그 선택을 해낸 당신을 위한 위로이다.
# 요약글: 넘어졌던 자리에서 한참을 머무른 적이 있습니다. 아무도 몰랐지만, 그 자리는 내 마음 한가운데였고, 나는 그곳에서 다시 걸을 용기를 찾고 있었습니다. 괜찮지 않았지만, 하루를 더 살아보기로 한 선택. 그 선택이 나를 지금 여기까지 데려왔습니다.이 책은 그런 마음에서 시작되었습니다. 완벽하지 않아도, 흔들려도, 다시 걷기로 한 사람들을 위한 글입니다. 실패와 후회, 기다림과 불안, 슬픔과 작아진 자존감을 안고 하루를 버텨낸 모든 이들을 위한 조용한 응원입니다. 이 책은 ‘잘 살아야 한다’는 다짐보다, ‘있는 그대로도 괜찮다’라는 믿음에 더 가까이 닿아 있습니다.이 책에는 특별한 정답도, 위대한 성취도 담겨 있지 않습니다. 다만, 오늘 하루를 무사히 살아낸 당신에게, 조용히 괜찮다고 말해주는 글들만 있습니다. 화려하지 않지만 단단한 말들, 실패한 날에도 당신을 붙잡아줄 한 줄의 문장이, 이 책 어딘가에 있기를 바랍니다.이 책은 누군가에 대한 조언이 아니라, 나에게 스스로 건네는 속삭임에 가깝습니다. 조용히 나를 다독이고, 천천히 내 마음을 이해하게 하는 글이 있습니다. 서둘러 읽지 않아도 됩니다. 필요한 순간, 필요한 페이지를 펼쳐 당신의 감정이 머무는 곳에 오래 머물러 주었으면 합니다. 이 책이 당신의 삶을 바꾸지 않아도 좋습니다. 그저 오늘의 당신을 있는 그대로 인정하는 데 작은 힘이 되어준다면, 그것으로 충분합니다.넘어지는 건 누구에게나 일어나는 일입니다. 하지만 다시 걷겠다는 다짐은 누구나 쉽게 할 수 없는 선택입니다. 이 책은, 당신을 믿고 그 선택을 해낸 당신을 위한 위로입니다.그리고 마지막 책장을 덮을 즈음, 당신의 마음속에도 이 문장이 조용히 머물기를 바랍니다.“넘어졌던 자리에서 다시 걸을 수 있다면 정말 괜찮습니다.”
# --------------------
# URL: https://indiepub.kr/product/로자-룩셈부르크/8276/category/24/display/1/
# 제목: 로자 룩셈부르크
# 한 줄 소개: 팔레스타인을 지지하는 유대계 좌파 페미니스트가 쓴 혁명가 로자 룩셈부르크의 최신 전기! 차별 받는 여성, 장애인, 유대인으로 평화와 혁명에 헌신하다 극우 군인들의 손에 살해 당한 로자 룩셈부르크의 삶과 투쟁.
# 요약글: 당대 가장 뛰어난 마르크스주의 이론가로 평가받는 로자 룩셈부르크는, 파업과 민주주의, 자본주의 수탈에 대한 분석으로 오늘날에도 큰 영향을 미치고 있다. 그녀는 1919년 1월 15일, 계엄령 치하의 베를린에서 극우파 군인들에게 살해당했다.로자 룩셈부르크가 세상을 떠난 지 100년이 지난 지금, 그녀의 유산은 무엇일까? 정치학자이자 무용가, 페미니스트이자 팔레스타인 평화 활동가인 다나 밀스가 로자 룩셈부르크의 저작과 편지를 통해 인류와 평등을 강조하고 혁명을 주장했던 그녀의 삶을 이야기한다.
# --------------------
# URL: https://indiepub.kr/product/여름으로-지어진-곳/8273/category/24/display/1/
# 제목: 여름으로 지어진 곳
# 한 줄 소개: 누구에게나 공간이 있다. 머물렀던 공간, 사랑하는 공간, 잃어버린 공간. 정원과 다림의 초원사진관, 리쯔웨이와 천윈루의 38레코드, 해준과 서래의 바다. 이처럼 내가 애정하는 영화들의 공간과 유사한 어딘가들이 이곳 소동, 여름으로 지어진 곳에 있다.
# 요약글: 오래도록 갖고 싶었던 영원한 관계. 우리는 잔잔한 호수를 만들어서 나눈다. 그 호수는 불안으로, 눈물로, 웃음으로, 포옹으로 지어진다. 너는 여름꽃 같고, 아침 하늘 같고, 새벽 비 같고 그러면서도 한없이 올곧은 수평선이나 사계절 내내 푸르른 금귤 나무 같다. 너와 함께한 계절은 내가 나를 처음 사랑한 때이기도 하다.찰나이기도, 영원이기도 했던 때.
# --------------------
# URL: https://indiepub.kr/product/닻/8270/category/24/display/1/
# 제목: 닻
# 한 줄 소개:
# 요약글: “닻으로 기억을 내리고 돛으로 다시 떠오르며 덫으로 마주한 고통마저 품는다.”70세 첫 시집, 삶의 파편들이 시가 되어 돌아왔다.『닻, 돛, 덫』은 심리학 교수이자 화가 그리고 인생 3막에서 ‘시인’이라는 또 하나의 이름을 얻은 오명자 작가의 첫 시집이다. 유년의 기억, 여성의 정체성, 가족, 상실, 노년의 자기 성찰까지. 저자는 70년 세월을 관통한 감정의 조각들을 ‘시’라는 형식으로 다듬어냈다.총 3부로 구성된 이 시집은1부 ‘닻’에서 삶의 뿌리와 유년의 기억2부 ‘돛’에서 성인으로서의 성장과 꿈, 사랑, 희망3부 ‘덫’에서는 고통과 회한, 고립, 그리고 내려놓음과 통찰을 이야기한다.세대를 초월해 공감할 수 있는 따뜻한 언어들노년의 눈으로 바라본 삶의 진솔한 통찰그리고 어릴 적 기다리던 ‘사탕’처럼 달고 씁쓸한 기억들이 고스란히 담겨 있다.읽는 이의 기억과 감정을 부드럽게 끌어올리며 다시 한 번 삶을 돌아보게 만드는 시집.
# --------------------
# URL: https://indiepub.kr/product/알을-두고-온-새의-마음/8269/category/24/display/1/
# 제목: 알을 두고 온 새의 마음
# 한 줄 소개: 스토리지 프레스 에세이 시리즈 #19삶이라는 숨바꼭질에서 매번 술래인 사람의 이야기 『알을 두고 온 새의 마음』
# 요약글: 하늘을 올려다보면 새 한 마리가 날아갑니다. 어디서건, 언제건 새는 꼭 하늘을 날고 있습니다. 작가의 말처럼 저곳으로 날아가는 새도 혹시 알을 두고 온 마음은 아닐까 가늠해 봅니다. 우리가 미처 발견하지 못했을 뿐, 새는 늘 하늘을 날아다니고 둥지를 오갑니다. 어쩌면 그는 남들의 몫까지 꿈을 꾸느라 피로한 새 한 마리가 아닐까요. 그에게 세상에서 가장 안전한 둥지를 선물하고 싶습니다. 맘 놓고 잠들고 깨어 알을 두고도 훨훨 날아다니다 돌아올 수 있을 테니까요.작가는 말합니다. “글쓰기는 쓰기 전에는 명분을 찾고, 쓸 때는 의미를 찾다가 다 쓰고 나면 가치를 찾아 떠도는 영원히 이길 수 없는 숨바꼭질의 술래가 되는 일”이라고. 그를 만나고 싶어졌습니다. 도서관에서, 복도식 아파트에서, 노을이 지는 옥상에서. 그가 둥지를 짓기 위해 찾는 작은 나뭇가지가 어디에 있는지 제가 알려줄 수 있을 것만 같습니다. 어쩌면 그 반대일까요. 그라면 술래를 자처하고, 가장 비밀스러운 장소를 슬쩍 일러주고, 주변을 서성이며 저를 찾지 못하는 척해줄 것 같습니다.우연과 인연의 귀함을 알고, 그 힘을 믿는 술래가 삶의 변두리를 어루만집니다. 동시에 “단단한 다정함”으로 한가운데를 관통하며 우리들의 둥지를 모아서 지은 아파트를 지킵니다. “어떤 슬픔일지만 궁금하다”는 말처럼 사람 냄새 풍기는, 그러니까 생활의 가치를 잘 아는 사람이기에 품을 수 있는 마음이지요.먼지 쌓인 선풍기를 해체하고 세척하기. 잘 마른 선풍기를 다시 조립하는 일. 글을 쓰거나 하루치 생을 살아가는 것과 다름이 없습니다. “마지막 나사를 힘껏 조이고 나면 종종 귀퉁이에 빠진 부품 하나가 반짝 빛”나는 경우도 더러 있습니다. 이 또한 우리네 삶의 모습이기도 하고요.목차에서 시선이 멈추는 속담을 골라 읽음은 어떨까요. 기왕이면 버스에서 말이죠. 당신이 탄 버스가 달립니다. 한산한 낮, 따스한 볕, 잠깐 터널을 지날 때의 쉼이 책과 함께 펼쳐집니다. 책을 덮고 창밖의 하늘을 내다보면 이번엔 새 떼가 하늘을 횡단하고 있을 것입니다. 같은 방향으로 날아가는 새들의 마음을 다시 한번 생각해 봅니다.
# --------------------
# URL: https://indiepub.kr/product/살아있는-보물지도의-비밀/8267/category/24/display/1/
# 제목: 살아있는 보물지도의 비밀
# 한 줄 소개: 그림을 그리고 책 읽는 것을 사랑하는 송성민 어린이 작가의 7살 순수한 시선에서 여행의 즐거움을 새롭게 풀어내어 책으로 담았습니다. 한국어와 영어가 병기되어 있고 그림, 스토리, 영어 번역까지 모두 완성한 그림책입니다.
# 요약글: 그림을 그리고 책 읽는 것을 사랑하는 송성민 어린이 작가의 7살 순수한 시선에서 여행의 즐거움을 새롭게 풀어내어 책으로 담았습니다.지난여름 하와이 여행을 통해 다른 세계로 가는 모습을 자유롭게 상상하여 표현한 작품입니다.바다와 물고기를 좋아하여 다양한 물고기와 동물들을 재미있고 다채로운 색깔과 그림으로 표현하여 나타내었습니다. 아이의 시선에서 표현된 상상의 세계를 볼 수 있습니다.
# --------------------
# URL: https://indiepub.kr/product/들켜도-망하지-않았으면-좋겠다/8265/category/24/display/1/
# 제목: 들켜도 망하지 않았으면 좋겠다
# 한 줄 소개: 어느 지구인의 미동의 과정
# 요약글: 너무 나 같은 이 책을 무어라고 소개하면 좋을까요. 하고 싶은 말, 그러나 입밖으로 꺼내지 못한 말을 쓰고서 엮었습니다. 일상과 영화, 일기와 편지 사이에서 사랑을 사랑한 흔적입니다.드러내고 싶은 마음과 감추고 싶은 마음은 왜 이리도 헷갈리게 뒤섞일까요. 부족한 소개는 책 속의 글에게 맡기려 합니다. 홀로 숱하게 읽어도 닳지 않던 문장, 이제 당신께서 읽어 주세요.소망 하나 있어요. 우리 망하지 말고 살아요.
# --------------------
# URL: https://indiepub.kr/product/긍정샐러드/8259/category/24/display/1/
# 제목: 긍정샐러드
# 한 줄 소개: 긍정샐러드와 함께 나만의 감정레시피를 만들고 불편하고 어려운 감정들을 다루어보세요. 균형잡힌 샐러드가 건강한 신체를 만드는 것처럼, 균형 잡힌 감정이 행복하고 주체적인 삶을 만듭니다. 이 책을 통해 멋진 감정 다이어터가 되어보세요.
# 요약글: 감정의 균형이 삶의 질을 결정한다.우리는 감정을 두려워하고, 때때로 감정에 휘둘린다. 기쁨조차 오래 즐기지 못하고, 분노나 외로움은 숨기거나 억누른다. 그 결과 감정은 복잡하고 불편한 존재가 되고 만다. 『긍정샐러드』는 이러한 감정에 대한 인식의 틀을 변화시키기 위한 워크북이다. 이 책은 감정은 억압하거나 통제해야 할 대상이 아니라 삶을 구성하는 ‘영양소’이며, 올바르게 다루면 우리를 더 단단하고 유연하게 만든다는 사실을 전달한다.『긍정샐러드』는 감정을 샐러드의 재료에 비유하는 독창적인 은유를 통해 방어를 내려놓고 보다 친근하게 내면의 경험을 다룰 수 있도록 돕는다. 각각의 감정에 대한 개인의 도식을 레시피에 비유해 마치 요리를 배우듯 감정을 다루는 법을 익히게 된다. 단순한 위로나 감정 분류를 넘어, 감정의 기능, 발생 조건, 다른 감정과의 조합 방식까지 심리학적 통찰을 바탕으로 구조화하여 제시한다.이 책은 독자가 직접 감정을 '손질하고 조리해보는' 과정을 경험할 수 있도록 구성되어 있다. 감정을 관찰하고 이해하며, 자신의 삶에 필요한 감정 조합을 실험해보는 이 실습은 감정이 버거운 현대인에게 자기 회복의 기회를 제공한다. 감정 표현이 서툰 청소년, 반복되는 번아웃에 지친 직장인, 창조적 영감을 필요로 하는 예술가, 그리고 감정 교육의 도구를 찾는 심리 전문가에게도 깊이 있는 가이드를 제공할 것이다.『긍정샐러드』는 감정을 단순한 심리 현상이 아니라 삶의 ‘도구’로 재발견하게 하는 책이다. 이 책은 감정의 무게에 눌려 있던 일상에, 기능적 감정 사용이라는 새로운 가능성을 열어준다. 이 책을 덮는 순간 우리는 감정을 균형 있게 즐기고 삶을 가꾸는 한 사람의 감정 다이어터로 변화했음을 경험하게 될 것이다.
# --------------------
# URL: https://indiepub.kr/product/파란인/8256/category/24/display/1/
# 제목: 파란인
# 한 줄 소개: 파란인, 파란을 만드는 자들
# 파란인들은 무엇이든 될 수 있다
# 각자의 위치에서 파란을 만드는 자들
#
# 단언한다
# 당신과 사랑 같은 것을 하면서 살아보겠다고
# 멀리서 보면 아마도 그런 시집이다
# 이 책은
# 요약글: 파란인, 파란을 만드는 자들파란인들은 무엇이든 될 수 있다각자의 위치에서 파란을 만드는 자들단언한다당신과 사랑 같은 것을 하면서 살아보겠다고멀리서 보면 아마도 그런 시집이다이 책은
# --------------------
# URL: https://indiepub.kr/product/파도에-지워진-어부의-시/8252/category/24/display/1/
# 제목: 파도에 지워진 어부의 시
# 한 줄 소개: 저녁노을이 서서히 시작되는 시간, 상도는 주저함 없이 바다 앞에 선다. 인연의 둥근 고리 끝에 마주 선 오상도의 다음 발자국은 어디일까. 석양을 밟으며 만난 파도, 그 파도는 아직도 어부의 시를 기다린다…….
# 요약글: 인생이라는 파도에서 자신만의 노를 저으며 살아가던 나룻배 사공 오상도가 칠흑 같은 역사의 질곡에서 살아남아 마침내 바다로 나아가는 이야기.
# --------------------
# URL: https://indiepub.kr/product/달팽이의-슬픔/8247/category/24/display/1/
# 제목: 달팽이의 슬픔
# 한 줄 소개: “이 슬픔을 어떻게 하면 좋을까요?” 일본의 안데르센 '니이미 난키치'의 동화 다섯 편을 선별한 그림책.
# 요약글: “이 슬픔을 어떻게 하면 좋을까요?”일본의 안데르센 '니이미 난키치'의 동화 다섯 편을 선별한 그림책.‘나’ 본연의 특별함을 알아가고 타자의 특별함을 알아보는 이야기.#달팽이의슬픔#자연 #그림 #어린이청소년일본 대표 아동문학가 니이미 난키치의 동화 다섯 작품 「달팽이의 슬픔」(표제작), 「꽃게 미용사」, 「작년에 만난 나무」, 「개구리 두 마리」, 「나무 축제」를 엮은 그림 동화 선집입니다.“나는 밤에 다니는 곤충이라 아무도 나랑 놀아주지 않을 거야.”“그렇지 않아.”서로의 장점을 발견하는 따뜻한 시선으로 쓰인 이야기들이, 저마다의 개성을 가진 이들이 모여 서로 이해하고 사랑할 때 하나의 조화로운 세상을 만들어갈 수 있다는 믿음을 전합니다.
# --------------------
# URL: https://indiepub.kr/product/그래서-제목이-뭔데-2/8244/category/24/display/1/
# 제목: 그래서... 제목이 뭔데? 2
# 한 줄 소개: '그림을 완성시켜주는 제목책'! 상상력과 표현력을 자극하는 책! 전세계가 주목하는 [ 작가 우갱 ]의 두 번째 책, '그래서 제목이 뭔데? 2'
# 요약글: 인문학의 완성, '제목'. '그래서 제목이 뭔데? 제 2권'은 '간단한 그림'과 그림 다음장의 '제목'으로 사랑, 기쁨, 슬픔, 재치의 감정을 전합니다. 여기서 제목은 단순한 보조요소가 아닌, 전달과 이해의 기폭제 역할을 합니다. 각자의 경험과 생각을 담아 독자 나름대로 감상한뒤, 다음장의 제목을 만나보세요. 제목을 보는순간 비로소 작가의 의도를 이해하며, 사색에 잠길 수 있는 것이 이 책의 독특한 재미입니다. 전세계가 주목하는 작가, '우갱'의 112점의 기발한 작품과 제목을 통해 무한한 상상의 세계로 떠나보아요!
# --------------------
# URL: https://indiepub.kr/product/내-이야기가-책이-되는-순간/8241/category/24/display/1/
# 제목: 내 이야기가 책이 되는 순간
# 한 줄 소개:
# 요약글: [처음 쓰는 나의 이야기, 세상에 닿다]“내 머릿속의 생각을 내 자신에게 먼저 보여주는 것이 중요하다. 어색해도 괜찮고, 아직 정리가 되지 않아도 괜찮다. 그 모든 것이 창작 과정의 일부니까.”SNS에 하루 한 줄씩 글을 쓰던 사람들이 ‘저자’라는 이름을 달고 한 권의 책에 모였다.이 책은 거창한 성공담도, 화려한 수식도 없다.그저 각자의 자리에서 묵묵히 살아낸 일상의 조각들을 진심으로 꺼내어 적은 문장들로 엮였다.《내 이야기가 책이 되는 순간》은 스레드(Threads)에서 글을 쓰며 살아가는 사람들이 ‘뷰이듀스 저자 오디션’이라는 새로운 형식의 온라인 행사를 통해 참여한 출간형 글쓰기 프로젝트의 기록이자 결과물이다.['책을 쓰게 된 사람들'의 도전기]처음엔 ‘내가 쓸 수 있을까’하는 마음을 품고 시작했지만,매일의 글 속에서 삶을 정리하고, 감정을 다독이며 결국은 자신을 더 잘 알게 된 사람들의 고백이 담겼다.이 책은 글을 쓰는 일이 삶을 어떻게 바꾸는지,그리고 한 사람의 ‘이야기’가 어떻게 ‘브랜드’가 될 수 있는지를 보여준다.《내 이야기가 책이 되는 순간》은"나도 할 수 있을까?"란 질문을"나도 한번 써보고 싶다"는 용기로 바꿔주는 책이다.[책은 완성되었지만, 이야기는 계속된다]이 책은 끝이 아니라 시작이다.책을 완성한 사람들이 다음에는 어떤 글을 쓰고, 어떤 삶을 만들어갈지, 우리는 응원하며 지켜볼 것이다.그리고 다음 ‘뷰이듀스 저자 오디션’에서는, 이 책을 읽은 당신의 이야기가 실릴지도 모른다.
# --------------------
# URL: https://indiepub.kr/product/고로-존재한다/8239/category/24/display/1/
# 제목: 고로 존재한다
# 한 줄 소개: 이 책은 일상에 대한 사건만을 기록하는 일반적인 기록장이나 다이어리가 아니다. 우리의 내면 깊은 곳에서 일어나는 여러 생각과 고찰을 기록할 수 있도록 안내하고, 나는 어떤 생각을 하고 사는 사람인지를 파악할 수 있게 해준다.
# 요약글: #나만의 생각 기록#읽고 쓰는 생각 노트“당신의 일상에서 스쳐 가는 소중한 생각을 지금 이 책에 기록하세요.”나조차 몰랐던 내 생각을 발견하고, 그것을 나만의 기록으로 만들도록 구성된 『고로 존재한다 - 읽고 쓰는 생각 노트』는 180도 펼쳐지는 하드커버 트윈링과 필기감이 좋은 종이로 제작되어 있다. 나는 물론, 생각나는 친구, 연인, 가족과 지인에게도 선물하기 좋은 책이다.이 책은 단순한 기록장이 아니다. 이 책에는 생각해 볼만한 33개의 다른 주제에 대한 글과 132개의 생각 질문이 담겨있다. 각 질문에 대한 답과 나만의 생각을 자유롭게 기록할 수 있는 넉넉한 노트 칸이 각 33개의 글을 잇따른다.이 책은 일상에 대한 사건만을 기록하는 일반적인 기록장이나 다이어리가 아니다. 우리의 내면 깊은 곳에서 일어나는 여러 생각과 고찰을 기록할 수 있도록 안내하고, 나는 어떤 생각을 하고 사는 사람인지를 파악할 수 있게 해준다. 이 책은 결국 나를 더욱 알아가게 해주는 도구로써, 지나치면 결국 휘발되는 작은 생각도 나만의 기록으로 만들 수 있게 한다.
# --------------------
# URL: https://indiepub.kr/product/사유하라/8238/category/24/display/1/
# 제목: 사유하라
# 한 줄 소개: 탄핵 심판 이후 주목해야 할 한 권의 책. 혼란과 갈등을 실천의 웃거름으로 전환하는 철학자 서용순의 열네 가지 제언.
# 요약글: 현대 프랑스 철학을 전공한 철학자이자, 한국과 세계의 정치·문화적 사유에 천착해 온 연구자 서용순의 첫 번째 산문집이다. 사유와 실천이라는 대주제 아래 ‘세대’와 ‘성차’를 비롯한 갈등 문제와 ‘사랑’, ‘자유’, ‘시’, ‘민주주의’에 이르는 현실적이고 시의성 있는 주제들을 다룬다. ‘에세이’로서 어렵지 않게 쓰였지만, 바디우와 플라톤에 대한 저자의 새로운 접근을 포함한 주요 철학적 개념을 적용함으로써, ‘철학’의 여지를 남겨놓았다. 특히 김수영, 신동엽, 고정희, 김민정 등 ‘새로운 사유’를 담아낼 ‘새로운 언어’로서의 시를 호출하고 철학적 접근을 시도한다. 탄핵 심판 이후 혼란한 사회 속에서 실천을 위한 위로와 용기가 필요한 독자, 바디우와 플라톤에 대한 입문용 해설서를 찾는 독자, 그리고 시를 쓰거나 읽으려는 독자 모두에게 참신한 지적 경험을 선사할 것이다.
# --------------------
# URL: https://indiepub.kr/product/쓰기로-다시-시작/8235/category/24/display/1/
# 제목: 쓰기로 다시 시작
# 한 줄 소개: “글쓰기는 나 쓰기다”마케터, 기획자, 디렉터, 작가이자 엄마로서의 주체적 삶을 담은 일상의 기록“이제 나는 멈추어도 멈추지 않는 삶을 산다.”새로운 시작을 꿈꾸는 여성, 엄마를 위한 공감과 위로의 에세이
# 요약글: 대기업의 마케터에서 두 아들의 엄마로, 엄마에서 기부 프로그램 기획자이자 콘텐츠 디렉터로 그리고 작가로 거듭난 정소령 작가의 공감과 위로의 에세이 《쓰기로 다시 시작》이 출간됐다. 작가는 누구보다 열심히 살았던 나의 시간이 멈춰버렸다고, 다시 돌아가고 싶어도 내 자리를 잃은 것만 같다고, 돈이 아닌, 나의 진정한 가치를 찾고 싶다고 생각하는 여성, 엄마들에게 새로운 자아를 찾는 여정을 솔직담백하게 이야기한다. 또한 예비 작가들에게 글쓰기나 책 쓰기를 기계적으로 추천하기보다 주체적 삶의 주인으로서 자신과 더 이상 멈춤 없는 일상과 인생을 찾길 권한다. 오롯이 자신을 위한 글쓰기를 시작하고 싶다면 누구든 지금이 바로 ‘쓰기로 다시 시작’할 시간이다.
# --------------------
# URL: https://indiepub.kr/product/자유형을-완벽하게-하는-방법/8230/category/24/display/1/
# 제목: 자유형을 완벽하게 하는 방법
# 한 줄 소개: 자유형을 완벽하기 위해 수영장에 가는 24살 이영. 꿈도, 희망도, 미래도 없이 오로지 수영에만 온 신경을 쏟는다. 강습을 같이 듣는 20살 해은을 만나게 되면서 인생이 점차 변하기 시작한다. 너무 다른 두 사람은 '수영'으로 뭉쳐 우정을 쌓는다.
# 요약글: 24살 ‘이영’은 불의의 사고로 피아노를 그만둔다. 손가락 재활을 위해 수영을 배우며 다시 피아노를 칠 날을 기대한다. 꾸준히 강습을 나가며 자유형을 배우는 이영. 그곳에서 함께 강습을 듣는 ‘해은’과 친해진다. 대학을 포기하고 우체국 직원이 된 해은과 평생 함께한 피아노를 그만둔 이영. 두 사람은 수영을 배우며 앞으로 나아간다. 과연 두 사람은 자유형을 완벽하게 할 수 있을까?
# --------------------
# URL: https://indiepub.kr/product/대머리는-수영모를-쓰지-않는다/8227/category/24/display/1/
# 제목: 대머리는 수영모를 쓰지 않는다
# 한 줄 소개: 16년 차 방송 예능작가의 좌충우돌 본업과 일인가구 여성으로서의 일상 에세이. 마음껏 슬퍼하고, 양껏 괴로워하고, 지독히 아파한 다음, 끝내는 웃음과 다정함을 찾아보자고 제안하는 이야기로서, 그녀의 삶에서 긍정의 태도가 어떻게 무르익게 되었는지 말한다
# 요약글: 여기, 위기와 좌절 속에서도 기어코 ‘유우머’를 발견해내는 사람이 있다. 그에게 유독 삶이 쉬웠을 리는 없다. 하지만 16년간 방송 예능 작가로 일해오면서 특유의 발칙하고도 참신한 시선을 얻게 된 덕일까, 그는 일상의 사소한 조각을 건져올리고 그 조각에 재미있는 이름을 붙일 줄 아는 사람이 되었다. 소중한 친구가 생면부지의 어린이에게 “대머리 빡빡이”라고 놀림받는 수모 속에서도, 하필 내 제육볶음은 양념이 환상이라 번번이 채식을 실패하는 아이러니 속에서도, 가끔 일인가구에 몰아닥치는 지독한 외로움에 눈물로 허덕일 때도…… 불평하고 화를 내기보단 깔깔 웃을 수 있다면 인생은 좀 더 살 만해지지 않을까? 그리고 그런 사람의 이야기가, 다른 사람을 한 번이라도 더 웃게 해줄 수 있지 않을까?
# --------------------
# URL: https://indiepub.kr/product/강아지책/8218/category/24/display/1/
# 제목: 강아지책
# 한 줄 소개: 우리는 헤어질걸 알면서도 사랑을 선택해.『강아지책』은 유기견 출신 반려견 8마리의 삶과 서사를 담은 에세이로, “유기견도 우리 곁의 반려견과 다르지 않다”는 메시지를 전달하는 독립출판 프로젝트입니다.
# 요약글:
# --------------------
# URL: https://indiepub.kr/product/서성이는-발걸음/8215/category/24/display/1/
# 제목: 서성이는 발걸음
# 한 줄 소개: 아직은 무의미의 가능성에 있는 것들 사이를 두려움과 설레는 마음으로 한 걸음씩 내딛으며 작은 샛길을 만들며 걸어가는 모든 정신적 산책자들을 위한 에세이집.
# 요약글: 이 책은 미술작가 홍보람이 《존재하기-위안의 형태들》과 《찰나의 존재들》 작업을 해나가면서 건져 올린 과정사진을 시와 같은 단상과 버무려 담은 에세이집입니다.작가는 2012년부터 제주에 거주하면서 자연의 형태들로부터 자신이 평소에 가져왔던 관계에 대한 질문에 답을 찾아나갑니다. 자연의 형태들로부터 위안을 받으며 형태에는 의지가 담긴다는 것을 배우고 자기 자신에게 그리고 타인에게 위안이 될 수 있는 형태를 직접 만들어내려고 부단히 노력합니다. 그 과정이 《존재하기-위안의 형태들》 부분에 담겨있습니다.작가는 또한 내가 존재하는 것과 같이 모든 것들도 지금 이 순간 함께 존재한다는 것을 늘 잊지 않으려고 노력합니다. 작가는 2011년부터 즉흥 음악을 하는 친구들과 음악이 그림이 되고 그림이 음악이 되는 즉흥그림을 그려왔는데요, 순간의 여러 가지 조건들에 의해 만들어지는 찰나를 보여주는 더할 나위 없이 좋은 방편이라 생각해 관객들을 공간에 초대해 즉흥의 순간을 함께 만들어내고 맙니다. 그 과정이 《찰나의 존재들》 부분에 담겨있습니다.매 순간 어디로 다음 발을 딛어야 하나 고민하고 주저하는 서성이는 발걸음이 이 책에 여린 궤적으로 남아있습니다. 이 순간들이 여러분의 일상의 순간과 닿길. 애써서 무언가 이루고자하는 무모하면서도 간절한 노력이 서로 공명하고 지지하기를 빕니다.
# --------------------
# URL: https://indiepub.kr/product/파도보다-더-높이/8214/category/24/display/1/
# 제목: 파도보다 더 높이
# 한 줄 소개:
# 요약글: 겹겹의 파도에도 무너지지 않을 단단하고 충만한 세계실패하고 좌절해도 분명 우리는 어디로든 나아갈 수 있을 것이란 믿음한국문학의 새로운 이름, 김준희의 첫 번째 소설집 『파도보다 더 높이』가 출간되었다. 이 소설집은 오늘을 살아가는 우리의 미세한 균열과 어긋남을 섬세하게 포착한다. 사회초년생, 전세 사기, 방치된 폐업 주유소, 명품주의, 아동 혐오, 교권 추락, 외국인노동자에 이르기까지 일곱 편의 이야기가 '사회 문제'라는 이음새로 느슨하게 연결되어 있다.김준희 소설에는 "허구를 빌미로 비현실적으로 과감해지려는 방탕한 객기"(전청림(문학평론가))가 없다. 소설 속 인물들은 번번이 좌절하고 슬픔의 수렁에 빠지지만, 김준희는 슬픔을 덧칠하지 않고 실패를 미화하지 않는다. 있는 그대로의 삶을 투명하게 그려내며 희망을 섣불리 약속하지 않는다. 그저 그들이 겪은 시간을 조심스럽게 끌어안는다. 무엇보다 삶이란 늘 실패와 좌절을 거듭하며 그럼에도 나아가야만 하는 일임을 조용히, 그러나 분명히 우리에게 건넨다. 그렇게 이 소설집은 세차게 휘몰아치는 세상으로부터 무너지지 않으려는 마음, 기어이 앞으로 나아가려는 몸짓으로 가득 채워져 있다.
# --------------------
# URL: https://indiepub.kr/product/하루와-클로버/8211/category/24/display/1/
# 제목: 하루와 클로버
# 한 줄 소개: 감정을 나누는 과정에서 성장과 변화를 겪는 하루의 이야기를 통해, 행복을 나누는 중요성과 그로 인해 찾아오는 기쁨을 전합니다.
# ...
# --------------------
# URL: https://indiepub.kr/product/혼잣말-모임/8114/category/24/display/1/
# 제목: 혼잣말 모임
# 한 줄 소개: 같은 회사에 다니는 5년 차 주임 정연과 1년 차 신입 윤아, 두 사람의 이야기를 담은 소설
# 요약글: <혼잣말 모임>은 같은 회사에 다니는 5년 차 주임 정연과 1년 차 신입 윤아, 두 사람의 이야기를 담은 소설입니다. 감정을 억압하는 정연의 이야기 「혼잣말 모임」과 '중간만 가자'를 모토로 살아온 윤아의 이야기 「플랫」. 두 편의 소설은 각 단편만으로 완결되는 동시에 서로 연결된 연작 소설입니다.소설 속 정연과 윤아는 '세상에 힘든 사람이 얼마나 많은데, 그만하면 행복한 거 아니야?'라는 말을 듣기 쉬울지도 모릅니다. 겉보기엔 별문제 없어 보이니까요. 때문에 자신의 상처나 아픔, 진정으로 바라는 바를 바로 보지 못합니다.어쩌면 우리 주변에 있는 보통 사람들의 삶도 그럴지 모르겠습니다. 다 그렇게 사니까 엄살 부리지 말라는 말 대신 서로의 사연을 귀 기울여 듣고 자신과 타인을 공감하길 바라며 이 책을 만들었습니다.
# --------------------
# URL: https://indiepub.kr/product/도대체-책방이-뭐라고/8113/category/24/display/1/
# 제목: 도대체 책방이 뭐라고
# 한 줄 소개: 수원에 있는 '그런 의미에서' 책방의 분투기로 매탄동에서 있었던 3년간의 이야기를 담았다.
# 요약글: 대학 졸업하기도 전에 저질러 버린 책방 창업!그러나 생각보다 너무 많이 힘든데?매일 안간힘을 짜내며 책방을 운영하는그런 의미에서 책방지기의 매탄동 분투기“읽는 사람이 쓰는 사람으로”라는 한 줄 소개를 갖고 있는 있는 그런 의미에서 책방은 2021년 수원의 매탄동에서 시작했다. 당시 주말 책방으로 운영하고 있던 곳이 문을 닫는다는 소식에 덜컥 인수해 버렸는데, 그때 책방지기의 나이는 스물일곱. 험난한 길을 선택하게 만든 단 하나의 문장, “3년하고 망해도 서른”은 책방을 시작하는 이유가 되기도 했지만 한편으론 책방을 그만둘 수 없게 만드는 문장이기도 했다. 힘들 때마다 딱 3년만 채우자, 더도 말고 덜도 말고 딱 서른까지만 해보자며 안간힘을 쓰고 버텼다.한파가 들이닥친 책방에서 추위를 이기기 위해 전기난로를 껴안고 있었지만 허리가 얼어붙기도 했으며, 비만 오면 스멀스멀 기어 나오는 하수구 냄새와 혈투를 벌이기도 했다. 욕심을 부리며 가지고 있는 현금을 모두 털어 넣어버리는 무리한 선택으로 밥을 굶기도 했다. 이때의 선택은 책방을 더 이상 이어갈 수 없다고 판단할 정도였다. 그러나 이렇게 힘든 상황이 이어져도 책방지기는 어떻게든 3년만 채우자며 넘어져도 무릎으로 기어가는 심정으로 버텼고, 결국 매탄동에서 3년을 채운 뒤 수원 행궁동의 새로운 공간으로 이사를 갔다.이 책에는 어리고 경험 없는 책방지기의 이야기가 고스란히 담겨 있다. 어떻게 하는지 몰라서 일단 해봤던 것들, 어김없이 따라 오는 실패. 그럼에도 곧바로 보완해서 도전하거나 언제든 다시 도전할 수 있도록 준비하는 모습을 보면 그가 3년을 마냥 버티기만 한 것이 아니라는 것을 알 수 있다.
# --------------------
# URL: https://indiepub.kr/product/개와-고양이-오래된-신문을-펼치다/8111/category/24/display/1/
# 제목: 개와 고양이, 오래된 신문을 펼치다
# 한 줄 소개: 《개와 고양이, 오래된 신문을 펼치다》는 50년간 신문에 실린 개와 고양이 이야기를 모아 그 시대 사람들과 동물들의 소중했던 순간을 되살려내는 책입니다.
# 요약글: 1930~1980년대는 대한민국 사회가 급격히 변모하던 시기로, 신문은 그 시대의 일상과 문화를 가장 생생히 담아내는 매체였습니다. 당시 신문에 실린 개와 고양이 관련 이야기는 단순한 동물 이야기 그 이상으로, 사람들의 가치관, 사회적 흐름, 그리고 인간과 동물의 관계를 보여주는 중요한 자료입니다. 이 도서는 당시 신문 속에 담긴 개와 고양이 이야기를 통해 시대상을 조명하고, 독자들에게 과거의 따뜻하고 정감 어린 이야기를 전하고자 합니다. 신문 속 개와 고양이, 잊혀진 이야기는 단순한 동물 이야기 모음집이 아닙니다. 이 도서는 20세기 중반의 신문 자료를 통해 과거의 삶과 정서를 재조명하고, 독자들에게 인간과 동물의 관계에 대한 깊은 통찰과 감동을 전달할 것입니다.
# --------------------
# URL: https://indiepub.kr/product/fragments-of-the-past/8109/category/24/display/1/
# 제목: Fragments of the Past
# 한 줄 소개: 오래된 흑백 사진들을 통해 인간과 반려동물의 변치 않는 사랑을 담아낸 책입니다. 단순한 사진 모음집을 넘어, 시간의 흐름 속에서 빛나는 특별한 관계를 조명합니다. 책장을 넘길 때마다 과거의 따뜻한 순간들이 되살아나는 듯한 감동을 느낄 수 있습니다.
# 요약글: 'Fragments of the Past: Dogs & Cats and Humans in Vintage Photographs'는 인간과 반려동물 간의 특별한 관계를 역사적으로 탐구하는 아름다운 책입니다. 이 책은 고전적인 흑백 사진을 통해 19세기와 20세기 초반의 사람들과 그들의 사랑스러운 개, 고양이들과의 교감을 담아냅니다. 각 사진은 단순한 기록이 아닌, 시대를 넘어서는 감동적인 이야기와 정서를 전달합니다. 사진 속 반려동물은 단순한 동물이 아닌, 인간의 삶의 중요한 일부분이자 감정적인 동반자로 등장하며, 그들의 존재가 인간에게 어떤 의미였는지를 엿볼 수 있습니다. 책은 빈티지 사진을 사랑하는 사람들에게는 물론, 반려동물과의 깊은 유대감을 나누고자 하는 독자에게도 큰 의미를 전달합니다. 고양이나 개와 함께한 순간들이 어떻게 세월을 초월해 오늘날까지도 사람들의 마음속에 남아 있는지를 다시금 상기시켜 줍니다.
# --------------------
# URL: https://indiepub.kr/product/수상한-양말/8107/category/24/display/1/
# 제목: 수상한 양말
# 한 줄 소개: 광주 대표 키즈 브랜드 mohani가 제작한순수 창작 동화책
# 요약글: < 수상한 양말 >은 사라져가는 옛 동네들에 대한 추억과 발자취를 주인공 아홉살 지용이의 시선으로 지역의 재개발 이슈와 함께 스토리텔링된 동화입니다.우리 아이들이 어린 시절의 따뜻한 기억들을 잊지 않고 살아가기를 바라는 마음을 그려냈습니다.작고 소중한 동네에 살아가는 수많은 지용이가다양한 아이들과 함께 공존하고 어울리며소중한 시절을 보내기를 바랍니다.한 아이를 키우려면 온 마을이 필요하듯,아이들을 위한 마음이 곧 우리 터전을 위한 마음입니다..
# --------------------
# URL: https://indiepub.kr/product/conceptzine-vol122/8105/category/24/display/1/
# 제목: CONCEPTZINE vol.122
# 한 줄 소개:
# 요약글: CONCEPTZINE vol.122 - ‘자기관리’EDITOR’S LETTER거래처와 미팅을 할 때면 가끔 이런 생각을 합니다. 마치 내가 면접 보러 온 사람이 된 것 같다는 생각이요. 물론, 그들은 이미 우리 회사가 그동안 작업했던 포트폴리오를 보고 연락을 준 거겠죠. 하지만 결국 직접 만나 대화를 나누면서 그들이 내게서 진짜 보고 싶은 건 ‘이 사람이 우리의 고민을 얼마나 성실히 들어주고, 얼마나 열정적으로 일을 함께 해줄 수 있을까?’ 하는 부분이 아닐까요?그렇다면 그들은 저의 어떤 모습을 보고 판단을 내리게 될까요?예전에 한번, 중요한 계약을 앞두고 미팅에 참석했던 적이 있어요. 그때 한창 바쁜 시기라 미용실을 몇 달째 가지 못해서 머리가 덥수룩했고, 하필 아침에 손톱깎이를 잃어버려 길게 자란 손톱도 깎지 못한 상태였는데요. 대화를 나누면서 문득 깨달았어요. ‘아…, 이분들은 지금 내옷차림이나 헤어스타일, 손톱 하나까지 다 보고 있을 수도 있겠다….’ 사실 마음속으로는 누구보다 진심으로, 이 일을 잘 해낼 자신이 있었지만, 상대의 눈에 비친 내 모습이 스스로를 충분히 돌보지 못한 사람처럼 느껴진다면 ‘나라도 일을 맡기고 싶지 않겠다’ 생각했습니다. 자기 자신을 소중히 다루지 못하는 사람이, 어떻게 타인의 일과 고민을 진심으로 소중하게 대할 수 있을지 의문을 가질 수도 있겠다 싶었죠.자기관리란 ‘내가 나를 소중히 여기는 마음’을 보여주는 시각적인 표현 아닐까요? 사람들은 내가 꾸미고 다니는 모습에서 단지 외형적인 아름다움이나 멋짐만을 평가하는 것이 아니라, 나 자신을 얼마나 소중하게 생각하고 있는지까지도 느끼는 것 같아요. 다시 말해, 자기관리는 “보세요, 제가 이렇게 완벽해요”라며 드러내는 자랑이 아닌, “저는 제삶을 소중히 여기고, 아끼며 사랑하는 사람입니다.그러니 저에게 맡겨주신 일이나 관계도 같은 마음으로 소중히 다룰 수 있습니다”라는 진심을 조용히 보여주는 마음의 표현인 셈이죠.이런 생각을 하게 된 그날 이후로, 저는 미팅이 있는 날이면 유독 외모에 신경을 씁니다. 제 이미지와 어울리는 스타일의 옷을 골라 잘 다려 입고, 머리와 손톱을 깔끔하게 정리하고, 가방과 신발에 묻은 얼룩은 없는지 세심하게 살피죠. 타인의 시선 때문이 아니라, 내가 나를 얼마나 소중하게 생각하고 있는지 조금 더 자신 있게 표현하고 싶으니까요.‘나는 나를 사랑하는 사람입니다’라는 표현이 삶에서 어떤 가치를 만들 수 있을까요? 이번 한 달은 내가 나를 얼마나 사랑하는 사람인지, 주변에 마음껏 표현해 보면 어떨까요?편집장 김경희
# --------------------
# URL: https://indiepub.kr/product/도망치듯-사랑을-말한다면/8104/category/24/display/1/
# 제목: 도망치듯 사랑을 말한다면
# 한 줄 소개: “미움도 때로는 사랑이라 했던가. 그동안 쓴 글들을 가만히 읽고 있으니 존재로부터 도망치듯이 사랑을 말하던 날들이 보였다.”선명하고 명쾌한 문장, 혐오와 맞서며 숨지 않는 마음 등의 평을 독자로부터 받는 희석 작가의 산문집. 50여 편의 글로 완성
# 요약글: “미움도 때로는 사랑이라 했던가. 그동안 쓴 글들을 가만히 읽고 있으니 존재로부터 도망치듯이 사랑을 말하던 날들이 보였다.”선명하고 명쾌한 문장, 혐오와 맞서며 숨지 않는 마음 등의 평을 독자로부터 받는 희석 작가의 산문집. 50여 편의 글로 완성된 이 책에는 세상이 규정하는 ‘온전한 시민’에서 벗어난 이야기, 차별과 혐오로 가득한 한국 사회 이야기, 독립출판사를 운영하며 먹고사는 이야기 등이 담겼다.작가는 그동안 세상이 싫고, 사람도 싫고, 모든 것들이 환멸 난다고 말하며 글을 썼지만, 그 글의 출발은 아이러니하게도 사랑이었다. ‘다 싫다’라는 헐렁한 변명으로 냉소적인 척 글을 썼으나, 속으론 이 세계를 진심으로 사랑했던 것. 이에 세상에 실망할 때마다 오히려 무엇을 바꿔야 하는지 작가는 적극적으로 외쳤다. 도망치듯이, 외면하듯이 사랑을 말하던 날들이 이 책을 만들어줬다.작가는 이번 책에 최대한의 솔직함, 예컨대 친부가 하루빨리 죽길 바라던 마음마저 거리낌 없이 담았다. ‘진실되게 쓰는 것’이 작가의 의무이자 독자에게 표현할 수 있는 감사함이기에 『도망치듯 사랑을 말한다면』에 쓸 수 있는 모든 걸 썼다.지금의 세상에서 산다는 것이 즐겁지 않은 사람이라면, 살아있다는 것이 자주 무력했던 사람이라면, 중심부가 아닌 주변부가 더 편한 사람이라면 『도망치듯 사랑을 말한다면』이 썩 괜찮은 책이 될 것이다.
# --------------------
# URL: https://indiepub.kr/product/유독-내가-싫은-날/8102/category/24/display/1/
# 제목: 유독 내가 싫은 날
# 한 줄 소개: 지친 청소년의 마음을 위로하는 청소년 그림책(14세 이상)
# 요약글: ‘숨어 버리고 싶은 날’ ‘도망치고 싶은 날’ ‘아무것도 하고 싶지 않고 아무도 보고 싶지 않은 날’ ‘놓아버리고 싶고 포기하고 싶은 날’을 지나면 결국 아무것도 해낼 수 없을 거라고 생각하는 날이 되는. 유독 내가 싫은 날 펼쳐들고 마음샤워를 하면 좋은 청소년들을 위한 그림책이다. 새로운 시선과 함께 참다운 나를 발견하게 해준다는 점에서 청소년 시기에 꼭 읽어야 할 책이다. 유독 ‘나’에 집중하며 위로하는 시간은 마음에 샤워를 하여 깨끗한 나로 거듭나는 시간임을 김민송 작가와 글과 이샛별 그림이 말해주고 있다.
# --------------------
# URL: https://indiepub.kr/product/아차어차여차하면-달라지는-단어들-일상의-재구성/8098/category/24/display/1/
# 제목: 아차어차여차하면 달라지는 단어들 : 일상의 재구성
# 한 줄 소개:
# 요약글: 우리는 살다보면 말로 인해서 많은 오해를 사고는 합니다. 아차, 이 말은 하면 안되는 거였는데. 어차, 이거 싸움 날 수도 있겠는데. 여차, 하면 오해를 사겠는데. 그것은 우리가 한국어라는 수단으로 이야기하고 있음에도 불구하고, 서로 안에 있는 단어의 정의가 다르기 때문입니다. 단어의 정의는 경험, 사상과 같은 것을 통해서 얼마든지 바뀔 수 있기 때문이죠. 우리는 생각합니다, 사람들의 안에는 개인만의 사전이 있다고. 단지 그걸 사전처럼 펼쳐볼 수 없을 뿐이라고. 한 번쯤 펼쳐만 보고 싶은 나만의 사전 1권, 일상편을 시작합니다.
# --------------------
# URL: https://indiepub.kr/product/아차어차여차하면-달라지는-단어들-관계의-재구성/8095/category/24/display/1/
# 제목: 아차어차여차하면 달라지는 단어들 : 관계의 재구성
# 한 줄 소개:
# 요약글: 우리는 살다보면 말로 인해서 많은 오해를 사고는 합니다. 아차, 이 말은 하면 안되는 거였는데. 어차, 이거 싸움 날 수도 있겠는데. 여차, 하면 오해를 사겠는데. 그것은 우리가 한국어라는 수단으로 이야기하고 있음에도 불구하고, 서로 안에 있는 단어의 정의가 다르기 때문입니다. 단어의 정의는 경험, 사상과 같은 것을 통해서 얼마든지 바뀔 수 있기 때문이죠. 우리는 생각합니다, 사람들의 안에는 개인만의 사전이 있다고. 단지 그걸 사전처럼 펼쳐볼 수 없을 뿐이라고. 한 번쯤 펼쳐만 보고 싶은 나만의 사전, 관계편을 시작합니다.
# --------------------
# URL: https://indiepub.kr/product/먹는다의-디자인/8092/category/24/display/1/
# 제목: 먹는다의 디자인
# 한 줄 소개: 음식에 대해 매우 이해하기 쉬운 방식으로 마음을 열어주는 인상적이고 매력적인 책입니다. 모든 페이지에 영감과 예시가 가득합니다. 이 책을 읽으며 음식에는 미식 외에도 더 발견할 수 있는 것이 많다는 것을 깨닫는 일은 너무나 기쁩니다. - 마리예 보헬장
# 요약글: 음식, 경험, 디자인 세 가지 키워드를 중심으로 작업을 전개하고 있는 스몰 바치 스튜디오 강은경 디자이너가 식경험 디자인에 대한 자신의 생각과 일에 대해 이야기 합니다.한글과 영어 두 가지 언어로 되어있습니다.
# --------------------
# URL: https://indiepub.kr/product/적어도-둘이라-좋아/8091/category/24/display/1/
# 제목: 적어도 둘이라 좋아
# 한 줄 소개: 이시경, 마손 작가 둘이서 11개의 글감을 쥐고 떠나는 글쓰기 여정. 일상과 내면의 감각을 깨우는 에세이이자 나의 글도 써 내려갈 수 있는 다정한 글쓰기 책. 6주간 두 작가와 함께 호흡을 맞춰 글을 써 볼 수 있는 빈자리도 마련되어 있다.
# 요약글: 함께 글을 쓰기 위해 필요한 정원은 '적어도 둘'. 두 명의 작가가 11개의 글감을 쥐고 떠나는 글쓰기 여정. 음악, 후각, 우리 동네, 계절, 사색, 관찰 등 글쓰기의 영감이 되어주는 감각적인 11개의 주제가 두 자루의 연필을 춤추게 한다.일상과 내면을 들여다보게 하는 에세이이자, 번져오는 영감으로 나의 이야기도 써 내려갈 수 있는 글쓰기 책. 6주간 함께 호흡을 맞춰 글을 써 볼 수 있는 다정한 빈자리가 마련되어 있다.
# --------------------
# URL: https://indiepub.kr/product/4주완성-쉬운데-그럴싸한-디지털드로잉/8087/category/24/display/1/
# 제목: 4주완성! 쉬운데 그럴싸한 디지털드로잉
# 한 줄 소개: 1주일에 4장씩, 4주동안 따라 그리면 그럴싸하게 디지털 드로잉을 할 수 있게 되는 책
# 요약글: 이 책은 태블릿 드로잉 앱 기초 사용법을 알고 있는 분들을 위해 만들어졌습니다.일주일 동안 이 책에 나온 각 주차별 4개의 교안을 순서대로 따라 그려 보세요.4주가 지나면 어느새 여러분도 그럴싸하게 디지털드로잉을 할 수 있습니다.
# --------------------
# URL: https://indiepub.kr/product/4주완성-쉬운데-그럴싸한-디지털드로잉/8084/category/24/display/1/
# 제목: 4주완성! 쉬운데 그럴싸한 디지털드로잉
# 한 줄 소개: 4주간 꾸준히 그리면 그럴싸하게 그릴 수 있는 디지털드로잉 책!
# 요약글: 이 책은 태블릿 드로잉 앱 기초 사용법을 알고 있는 분들을 위해 만들어졌습니다.일주일 동안 이 책에 나온 각 주차별 4개의 교안을 순서대로 따라 그려 보세요.4주가 지나면 어느새 여러분도 그럴싸하게 디지털드로잉을 할 수 있습니다.
# --------------------
# URL: https://indiepub.kr/product/열매를-맺기-위해-준비하는/8082/category/24/display/1/
# 제목: 열매를 맺기 위해 준비하는
# 한 줄 소개: 청소년 친화적인 독립출판사 앵두책방에서 진행하는 [꿈꾸는 청소년 자서전 프로젝트] 시리즈의 첫 번째 출판물입니다. 『열매를 맺기 위해 준비하는』의 저자 체리리는 어릴 적엔 '평범함'을 꿈꾸었고, 지금은 '개성'과 '연대', '성숙해지기'를 꿈꿉니다.
# 요약글: '꿈꾸는 청소년 자서전 프로젝트'의 첫 번째 저자 체리리평범하고 싶었던 따라쟁이 아이가 주체적인 삶을 살기까지의 이야기!평범하고 싶었다. 평범하게 사랑받고 평범하게 먹고 사는 그런 사람이 되고 싶었다. 평범하지 않으면 안 될 것 같았다.하지만 나는 '평범함'이라는 꿈을 이루지 못했다. 나는 누구보다도 특별하기 때문이다. 우리 모두 그렇다. 우리는 모두 다 다른 삶을 살아 열매를 맺고, 각자의 씨앗을 존중받는다.다시는 '평범함'과 같은 꿈을 좇으며 나를 깎아내리지 않기로 결심했다. 대신 나는 '개성'과 '연대'라는 비전을 꿈꾸는 특별한 사람이 될 것이다. 나는 특별하기 때문에 매일 하루도 찬란하다. 나의 벚꽃 시절도, 푸르른 잎사귀 시절도, 단단한 체리 시절도 흐드러지게 빛날 것이다. 그래서 나는 푸르른 잎처럼 떨어지는 벚꽃을 흘려보내며 새로운 체리 열매를 기대하기로 했다.
# --------------------
# URL: https://indiepub.kr/product/해를-쫓는-아이들/8080/category/24/display/1/
# 제목: 해를 쫓는 아이들
# 한 줄 소개: 오랜 시간을 돌고 돌아도 만나고 싶은 누군가가 있으신가요?
# '인연'과 '사랑'의 신비로운 비밀을 알려주는 상징 동화!
# 요약글: 그리스 로마 신화, 성경, 파우스트 등 고전 속 신화와 상징들을 이어 이뤄진 어린이와 어른이 모두를 위한 이야기. 해를 만지러 가던 소년 ‘한’은 ‘담’이라는 말을 타고 온 소녀, ‘연’을 만난다. 그러던 어느날 갈림길이 나타난다. 한쪽은 바다, 다른 한쪽은 산으로 나있었다. 그런데 한과 연의 의견은 다르다.둘의 의견은 끝까지 다르다. 결국 한이 잠든 사이, 연은 담을 한에게 남겨두고 떠난다. 잠에서 깬 한은 슬퍼하면서도, 해를 쫓아 터벅터벅 산으로 발길을 향한다. 산 정상으로 이르는 길목에서 한은 다양한 인물들을 만나고, 그들은 한에게 저마다의 이야기를 들려준다. 한은 어떤 이야기를 들었을까? 그리고 한은 어떤 이야기를 만들어갈까? 소년과 소녀는 해를 만질 수 있었을까?
# --------------------
# URL: https://indiepub.kr/product/머어얼리/8079/category/24/display/1/
# 제목: 머어얼리
# 한 줄 소개: 어디론가 머리 떠나고 싶은 사람들에게 전하는 이야기 입니다.
# 떠나고 싶지만 떠날 수 없는 사람. 떠날 수 있지만 떠나지 못하는 사람.
# 몸이 불편하거나 어딘가에 얽매여 있고 마음이 아픈 사람들 그리고 이 세상 모든 생명들이 떠날 수 있기를 응원합니다.
# 요약글: 무리 속 개미와 아이가 떠나는 상상을 그린 그림책입니다.
# --------------------
# URL: https://indiepub.kr/product/날씨-소나기/8076/category/24/display/1/
# 제목: 날씨 '소나기'
# 한 줄 소개: 주인공 ‘바다’가 이별과 사랑에 대한 자신만의 답을 하나씩 찾아가는 소설. 총 3부로 나뉘어져 있으며, 누구나 맞닥뜨렸을 사랑에 대한 고민을 담았다.
# 요약글: 《날씨 ‘소나기’》는 이별과 사랑에 대한 고찰을 담은 작품입니다.주인공 ‘바다’는 6년간의 연애를 이별로 마무리했습니다. 누구에게나 그렇듯 이별은 벅찬 것이고, 바다는 벅찬 감정을 다스리지 못해 지쳐갑니다. 하지만 ‘바다’는 이별의 슬픔을 극복하고 싶지만, 극복하고 싶지 않다는 양가적인 감정을 가지고 있습니다. 그녀에게 있어서 상실의 아픔이란 피하고 싶은 것인 동시에 그녀의 지난 사랑이 진실했다는 증거이기 때문입니다. 이야기는 이런 혼란스러운 바다의 감정을 따라가며 진행됩니다.소설은 총 3부로 나뉘어져 있으며, 각 챕터마다 바다는 나름의 답을 하나씩 찾아갑니다. 바다가 찾은 답이 정답인지 아닌지는 모릅니다. 중요하지도 않습니다. 바다에게 중요한 것은 ‘그녀에게 평안이 찾아왔는가?’라는 질문이고, 우리에게 중요한 것은 ‘우리의 답은 무엇인가?’이니까요.이것은 이별에 관한 이야기입니다. 그리고 이별에 대한 이야기는 필연적으로 사랑에 대한 이야기일 수밖에 없습니다. 사랑이 없는 이별은 존재하지 않기 때문입니다. 그러니 이것은 이별소설인 동시에 연애소설이기도 합니다. 마치 바다의 감정이 양가적이었던 것처럼 말이죠.
# --------------------
# URL: https://indiepub.kr/product/깨어난-자유/8072/category/24/display/1/
# 제목: 깨어난 자유
# 한 줄 소개: 깨어난 자유는 철학적 통찰과 개인적 성찰이 잘 어우러진 책으로, 보편적이면서도 깊이 있는 주제들을 다루고 있습니다. 저자는 일련의 도발적인 에세이를 통해 독자들에게 사회적 규범에 대해 질문을 던지며, 자신의 삶과 선택을 돌아보도록 합니다.
# 요약글: 깨어난 자유는 인간의 존재와 욕망, 그리고 의미를 찾는 여정을 깊이 탐구한 철학적인 책입니다. 저자는 행복, 실패, 삶의 역설, 그리고 진정성 있게 살아가는 것의 가치를 주제로 하여 독자들에게 현대 사회 속에서 자신만의 자유를 찾도록 독려합니다. 존재의 혼돈 속에서 스스로를 돌아보고, 사회적 규범을 넘어서는 삶의 의미를 찾아가는 여정으로 독자들을 초대합니다.
# --------------------
# URL: https://indiepub.kr/product/매달리는-기쁨/8071/category/24/display/1/
# 제목: 매달리는 기쁨
# 한 줄 소개:
# 요약글: 책방을 운영하며 폐업을 고민해 인스타그램에 글을 올리고, 긴 방학을 알리기도 했습니다. 하지만 다행히도 어찌저찌 버텨내며, 오는 25년 5월이면 어느덧 5년을 채우게 됩니다. 《매달리는 기쁨》은 아무도 이해하지 못하고, 때로는 나조차 이유를 모른 채 온힘을 다해 매달리는 것들에 대한 이야기입니다. 멈출 듯 멈추지 않고 계속 나아가는 사람들, 그리고 그런 이들을 향한 마음을 써 내려갔습니다. 한 사람이 쌓아 올린 마음과 그 진정성 어린 시간을 함께 통과하며, 어디서든 조금 더 매달릴 수 있는 힘을 얻기를 바랍니다. 무언가를 계속해 나가는 사람만이 알 수 있는 기쁨이 온전히 전해지길 바랍니다.
# --------------------
# URL: https://indiepub.kr/product/마음을-안는-마음/8067/category/24/display/1/
# 제목: 마음을 안는 마음
# 한 줄 소개: 칠 년간의 직장 생활을 마치고, 삶의 변화를 마주한 길목에서 그려낸 마음의 기록. 퇴사 후 홀로 길을 걸으며 마주한 고뇌와, 독립출판을 하며 글을 쓰고 책을 엮는 삶, 그리고 사람들과의 연결 속에서의 마음을 솔직하게 담았습니다.
# 요약글: “홀로 서는 마음, 그리고 이어지는 삶”『마음을 안는 마음』은 칠 년간의 직장 생활을 마치고, 삶의 변화를 마주한 길목에서 그려낸 마음의 기록입니다.퇴사 후 홀로 길을 걸으며 마주한 고뇌와, 독립출판을 하며 글을 쓰고 책을 엮는 삶, 그리고 사람들과의 연결 속에서의 마음을 담았습니다.IT 개발자로 버티며 지나온 시간들이 마치 나에게서 멀어지는 길을 걷는 것처럼 느껴져, 더 멀어지기 전에 걸음을 멈추었습니다. 퇴사 후 혼자 걷는 시간이 길어지며 외로움에 잠식된 날들도 많았지만, 글을 쓰고, 요가 수련을 하고, 가족과 친구들, 그리고 독립 출판을 시작하며 맺어진 인연들과 마음을 나누며 알게 되었습니다. 혼자라 여겼던 나날 속에서도, 사실은 결코 혼자가 아니었음을, 누군가는 조용히 곁을 지켜주고 있었다는 것을요.지나온 길 위에 새겨진 흔적이 모나고 부족했을지라도, 그 작은 흔적들이 언젠가 누군가와 이어지는 선이 되고, 새롭게 나아갈 목적지가 될 것이라 믿으며 스스로 선택한 방향으로 나아가는 여정에서의 마음을 솔직하게 담았습니다.삶의 전환점 앞에 서 계신 분, 길목 위에 잠시 멈춰 선 분, 그리고 누군가의 위로와 온기가 필요한 분들께 이 책이 작은 위안으로 닿았으면 좋겠습니다.
# --------------------
# URL: https://indiepub.kr/product/樂-step-요즘엔-스윙댄스를-추고-있습니다/8061/category/24/display/1/
# 제목: 樂, STEP - 요즘엔 스윙댄스를 추고 있습니다
# 한 줄 소개: 스윙댄스를 추는 23명의 이야기를 엮은 앤솔로지 에세이.
# 첫 스텝의 설렘, 춤이 된 일상, 리듬 속에 새긴 흔적들.
# 춤을 아는 이에게는 익숙한 리듬으로, 모르는 이에게는 새로운 스텝으로.
# 이 책이 당신에게 한 스텝 다가갑니다.
# 요약글: 『樂, STEP – 요즘엔 스윙댄스를 추고 있습니다』한 걸음 내디디면, 음악이 몸을 감싸고, 낯선 손이 맞잡힌다.그렇게 우리는 춤을 춘다.『樂, STEP – 요즘엔 스윙댄스를 추고 있습니다』 는스윙댄스를 추는 23명 각자의 이야기를 엮은 앤솔로지 에세이다.처음 스텝을 내디딘 순간, 춤이 일상이 된 과정,음악과 리듬 속에서 스윙댄서 각자의 삶에 새긴 흔적들을 풀어놓는다.누군가는 우연히 스윙댄스를 마주했고,누군가는 긴 시간 춤을 곁에 두었다.어떤 이는 그저 춤을 사랑할 뿐이지만,또 어떤 이는 춤을 통해 자신을 사랑하는 법을 배워간다.서로 다른 삶을 살아온 이들이 같은 비트를 밟으며 연결된다.발걸음 하나, 손끝의 작은 신호에도 마음을 주고받는 순간.그 감각을 이 책 속에서 마주할 수 있기를.춤을 알고 있는 사람들에게는 익숙한 리듬으로,춤을 모르는 사람들에게는 새로운 스텝으로,이 책이 반가운 인사가 되기를 바라며,당신에게 한 스텝 다가갑니다.
# --------------------
# URL: https://indiepub.kr/product/산책가자/8059/category/24/display/1/
# 제목: 산책가자
# 한 줄 소개: 대형견 '밥풀'과 함께 매일 아침,저녁으로 서울의 한강공원을 산책하면서, 한강의 사계절과 반려견의 모습을 담은 필름 사진집입니다.
# 요약글: 한강의 산책자는 "산책가자." 네 음절을 힘차게 외치면서 오늘의 하루를 시작한다. 하루에 두 번, 매일 아침,저녁 한강을 산책한다. 래브라도 리트리버 '밥풀'과 함께. 마포대교를 기점으로 양화대교와 동작대교 사이 한강의 북단을 걷는다. 흐린 날에는 일 만보 쯤, 걷기 좋은 날씨엔 이 만보도 거뜬히 걷는다. 비가 오나 눈이 오나, 매일 같은 시간 같은 길을 걸으며 서울의 한강을 사유한다. 서울에서 나고 자란 탓에 뻔해 보이던 한강도날씨와 계절에 따라, 혹은 산책자의 기분에 따라 다양한 얼굴이 존재한다는 것을 깨닫게 된다. 그리고 세상에서 산책을 가장 좋아하는 반려견 밥풀과 함께 한강을 걸으면서 가까운 곳에서 행복을 발견한다. 이전에는 일부러 먼 곳으로 여행을 떠나 낯선 도시에서 낯선 행복을 찾았다면, 지금은 보통날 함께 한강을 걷는 낯익은 행복의 조각들로 삶을 채운다. 오늘도 산책으로 하루를 시작하고, 산책으로 하루를 끝맺는다. 내일은 비가 오지 않았으면 좋겠다.
# --------------------
# URL: https://indiepub.kr/product/일기를-쓰려는데-아무일도-없었어/8057/category/24/display/1/
# 제목: 일기를 쓰려는데 아무일도 없었어
# 한 줄 소개: "일기도 하나의 장르" 하루를 영감으로 한 페이지를 남긴다. 과거의 내가 남긴 기록에서 위로를 받고 영감을 받아 현재를 살아가며 미래를 그린다. 이 책을 다 읽고 나면 당신도 자꾸만 들춰보고 싶은 일기장일 생길지도 모르겠다.
# 요약글: "일기도 하나의 장르"하루를 영감으로 한 페이지를 남긴다.남기고 싶은 마음과 장면을 나열하다 보면 기록은 더 단단해지고 일상을 살아가는 힘이 된다.과거의 내가 남긴 기록에서 영감을 받아 현재를 살고 미래를 그려나가고 있다.저자는 다정하고 위트 있게 사사로운 기록의 운치를 전한다.이책을 다 읽고 나면 당신도 자꾸만 들춰보고 싶은 일기장이 생길지도 모르겠다."누군가의 경험이 우리의 경험이 되고 추진력이 될 수 있도록."
# --------------------
# URL: https://indiepub.kr/product/떠나고-남았다/8055/category/24/display/1/
# 제목: 떠나고, 남았다
# 한 줄 소개: “떠날 자유와 머물 용기가 필요한 당신!”좋은 삶의 길을 찾고 있는 당신에게, 떠남과 도전의 진짜 의미를 묻는다.당신은 지금 행복한가요?‘우리가 정말 원하는 삶을 위해, 어떻게 용기를 낼 것인가? ’이 질문의 답을 찾는  이야기
# 요약글: '떠나고, 남았다'는 한 중년 남자가 '좋은 삶'의 의미를 찾아가는 여정을 담았다. 저자는 중년 이후의 삶에 대해 고민하는 이들에게 '늦은 도전'이 아니라 '새로운 시작'이 가능하다는 메시지를 전한다. 또한 자녀를 키우는 부모로서, 아이들에게 어떤 삶을 물려줄지에 대한 깊은 고민이 녹아 있다. "부모가 안정적인 길을 걸어야 한다."는 세상의 상식과 정반대로, 그는 자신의 삶 자체가 자녀들에게 가장 큰 유산이 될 것이라 믿는다.스리랑카에서 실패와 좌절을 맛보면서도 다시 도전하는 과정은 단순한 여행 에세이가 아니다. 이 책은 ‘생활실험자의 기록’이자 ‘실패한 사업가의 도전장’이며, 동시에 ‘행복한 삶을 찾아가는 실험 보고서’다. 10년 동안 20번 넘게 스리랑카를 오가며 겪은 문화적 충돌과 시행착오, 그리고 그 속에서 발견한 ‘진짜 행복’을 이야기한다.특히, 자녀 교육과 중년 이후의 삶에 대한 고민을 가진 이들에게 이 책은 특별한 의미를 가진다. 저자는 ‘아빠처럼 살아도 괜찮을까?’라는 질문을 던지며, 기존의 교육관을 뒤집는다. 학원이 아니라 여행으로 아이들을 키운 이야기, 부모로서의 불안과 새로운 삶에 대한 도전, 그리고 스리랑카에서 찾은 행복의 순간들을 솔직하게 기록했다.이 책은 단순한 성공 스토리가 아니다. 오히려 실패 속에서 더 단단해진 한 남자의 기록이다. 그리고 그것이야말로 더 많은 사람들에게 공감과 위로를 줄 것이다. “떠나는 것보다 더 중요한 건, 무엇을 남길 것인가”라는 질문이 남는 책,'떠나고, 남았다'는 독자에게도 새로운 삶을 꿈꾸게 할 것이다.
# --------------------
# URL: https://indiepub.kr/product/어쩐지-제주에-오고-싶었어/8054/category/24/display/1/
# 제목: 어쩐지 제주에 오고 싶었어
# 한 줄 소개: 서른여섯, 익숙한 삶을 떠나 제주에서 보낸 6개월.
# 나만의 방, 새로운 루틴, 소풍 같은 하루들.
# 제주의 자연 속에서 쌓은 기록이 새로운 시작을 꿈꾸는 이들에게 작은 용기를 전합니다.
# 요약글: 서른 여섯 서울 여자는 남편을 두고 혼자 제주로 오게 됩니다.이사 시작일부터 6개월동안의 제주 일상이 이야기입니다.나만의 방을 계약하는 날부터 하고 싶은 일을 찾게되는 순간까지,꿈꾸던 라이프 스타일을 만들어 건강한 루틴을 갖게 되는 과정과숲, 바다, 오름, 산, 섬 등의 자연 속을 거닐며 소풍 같은 하루하루를 보낸 사진과 단상들이 담겨 있습니다.
# --------------------
#
# 총 120개의 책 상세 정보를 추출했습니다.

# %% [markdown]
# ## 키워드 추출 방법 선택
#
# ### Subtask:
# 출력 텍스트를 검토한 후, 텍스트를 결합할지 분리할지 계획합니다.
#
# 텍스트에서 핵심 키워드를 추출하는 방법을 선택합니다. (예: 빈도 분석, TF-IDF, 자연어 처리 라이브러리 사용 등)

# %%
# 텍스트 데이터 특성 고려:
# - 한글 텍스트
# - '제목', '한 줄 소개', '요약글'이 합쳐져 있어, 짧은 핵심 문구부터 비교적 긴 설명까지 다양함.
# - 책의 주제를 나타내는 명사나 명사구가 핵심 키워드가 될 가능성이 높음.

# 키워드 추출 방법 선택:
# 한국어 텍스트 분석에는 형태소 분석이 필수적입니다.
# 'konlpy' 라이브러리의 'Okt'(Open Korean Text) 형태소 분석기를 사용하여 텍스트를 명사 단위로 분해하고,
# 이 명사들 중에서 빈도가 높은 단어들을 추출하는 방식을 사용합니다.
# 추가적으로, TF-IDF (Term Frequency-Inverse Document Frequency) 기법을 활용하여
# 문서 집합 내에서 특정 문서에만 자주 나타나는 중요한 단어를 식별하는 것도 고려할 수 있습니다.
# 그러나 여기서는 각 책별 핵심 키워드를 파악하는 것이 주 목적이므로,
# 1차적으로 형태소 분석 후 명사 빈도 분석을 사용하는 것이 직관적이고 효과적일 것으로 판단됩니다.
# 특히 '제목'과 '한 줄 소개' 같은 짧은 텍스트에서도 의미 있는 명사를 놓치지 않고 추출할 수 있습니다.

# 선택한 방법 설명 및 이유:
# - 방법: konlpy 라이브러리의 Okt 형태소 분석기를 사용하여 각 책의 결합된 텍스트에서 명사를 추출하고, 추출된 명사들의 빈도를 계산하여 상위 N개의 단어를 키워드로 선정합니다. 불용어 제거 과정을 추가하여 분석의 정확도를 높일 수 있습니다.
# - 이유: 한국어는 띄어쓰기만으로는 단어를 구분하기 어렵기 때문에 형태소 분석이 필수적입니다. Okt는 비교적 사용하기 쉽고 성능이 준수하여 한국어 텍스트 분석에 널리 사용됩니다. 명사는 텍스트에서 핵심적인 의미를 담고 있는 경우가 많으므로, 명사 빈도 분석은 텍스트의 주요 주제를 파악하는 효과적인 방법입니다. TF-IDF는 문서 간 중요도를 비교하는 데 유용하지만, 단일 문서(각 책)의 핵심 내용을 파악하는 데는 단순 빈도 분석이 더 직접적일 수 있습니다.

# %% [markdown]
# ## 키워드 추출 실행
#
# ### Subtask:
# 선택한 방법(konlpy Okt를 이용한 명사 추출 및 빈도 분석)을 사용하여 각 책 정보에서 키워드를 추출합니다.
#
# 다음 단계에서는 선택한 방법(konlpy Okt를 이용한 명사 추출 및 빈도 분석)을 사용하여
#
# 'all_book_details' 리스트의 각 책에 대해 키워드를 추출하는 코드를 작성합니다.
#
# 불용어 리스트를 정의하고 적용

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (1.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from konlpy) (5.4.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.12/dist-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from JPype1>=0.7.0->konlpy) (25.0)

# %% [markdown]
# ## 책의 주제를 파악하기 위해서 책 제목 + 한줄 소개 + 요약글을 합쳐 빈도분석 TF-IDF 방식을 사용함

# %%
from konlpy.tag import Okt
from collections import Counter

# 1. `konlpy` 라이브러리에서 `Okt` 형태소 분석기를 임포트합니다. (already imported above)
okt = Okt()

# 2. 불용어 리스트를 정의합니다.
# 일반적인 한국어 불용어 및 책 내용과 관련된 일반적인 단어 추가
stopwords = set([
    '은', '는', '이', '가', '을', '를', '과', '와', '하다', '이다', '있다', '없다',
    '에서', '으로', '에게', '에게서', '한테', '한테서', '이다', '아니다', '되다', '하다',
    '같다', '같습니다', '같아요', '같습니다', '같은', '같은데', '같은데요',
    '되다', '됩니다', '되었어요', '되었습니다', '되는데', '되는데요',
    '있다', '있습니다', '있어요', '있는데', '있는데요',
    '없다', '없습니다', '없어요', '없는데', '없는데요',
    '책', '이야기', '내용', '부분', '수', '것', '곳', '때', '점', '분', '말', '글', '저자', '독자',
    '사람', '우리', '모든', '다양한', '많은', '어떤', '이런', '그렇다', '그리고', '하지만', '그래서',
    '통해', '대해', '따라', '위해', '대한', '처럼', '만큼', '같이','이자',
    '이번', '지난', '다음', '각자', '서로', '함께', '다시', '정말', '가장', '더욱', '조금', '아마',
    '~다', '~하다', '~이다', '~되다', '~습니다', '~어요', '~는데', '~데요',
    '페이지', '작가', '작품', '출판', '출간', '소설', '시집', '에세이', '그림책', '독립출판',
    '이번호', '매거진', 'vol', 'no'
])


# 3. 각 책의 정보를 담고 있는 `all_book_details` 리스트를 반복합니다.
for book in all_book_details:
    # 4. 각 책에 대해 '제목', '한 줄 소개', '요약글' 필드의 텍스트를 하나의 문자열로 결합합니다.
    # 필드가 없을 경우를 대비해 .get() 사용
    combined_text = book.get('제목', '') + ' ' + book.get('한 줄 소개', '') + ' ' + book.get('요약글', '')

    # 9. 키워드 추출 과정에서 발생할 수 있는 예외(예: 텍스트가 비어있는 경우)를 처리합니다.
    if not combined_text.strip():
        book['키워드'] = [] # 텍스트가 비어있으면 키워드 리스트를 비워둡니다.
        print(f"경고: {book.get('URL', '알 수 없는 URL')} 의 텍스트가 비어있어 키워드를 추출할 수 없습니다.")
        continue

    try:
        # 5. 결합된 텍스트에 대해 `Okt` 형태소 분석기를 사용하여 명사를 추출합니다.
        nouns = okt.nouns(combined_text)

        # 6. 추출된 명사 리스트에서 정의된 불용어를 제거합니다.
        filtered_nouns = [noun for noun in nouns if noun not in stopwords and len(noun) > 1] # 한 글자 명사 제외

        # 7. 불용어가 제거된 명사들에 대해 빈도를 계산합니다.
        noun_counts = Counter(filtered_nouns)

        # 8. 계산된 빈도를 바탕으로 각 책별 상위 N개 (예: 10개)의 명사를 해당 책의 키워드로 저장합니다.
        # 상위 10개 키워드 추출
        top_keywords = [keyword for keyword, count in noun_counts.most_common(10)]

        # 이 키워드를 `all_book_details` 리스트의 해당 책 정보 딕셔너리에 새로운 키('키워드')로 추가합니다.
        book['키워드'] = top_keywords

    except Exception as e:
        # 형태소 분석 중 발생할 수 있는 다른 예외 처리
        book['키워드'] = []
        print(f"오류 발생: {book.get('URL', '알 수 없는 URL')} 에서 키워드 추출 중 오류 발생 - {e}")


# 결과 확인 (처음 몇 개의 책에 대해 추출된 키워드 출력)
print("\n--- 추출된 키워드 확인 (처음 5개 책) ---")
for i, book in enumerate(all_book_details[:5]):
    print(f"Book {i+1}: {book.get('제목', 'N/A')}")
    print(f"  키워드: {book.get('키워드', '키워드 추출 실패')}")
    print("-" * 20)
# Out:
# --- 추출된 키워드 확인 (처음 5개 책) ---
# Book 1: 이러나저러나 불편한 거야 불편한 건
#   키워드: ['감정', '가지', '이름', '마주', '그대로', '자주', '기록', '불안', '후회', '무기']
# --------------------
# Book 2: 불안과 밤 산책
#   키워드: ['불안', '산책', '기록', '당신', '하루', '마음', '내기', '아침', '문득', '우울']
# --------------------
# Book 3: 속속들이 독립출판 알고 보니 의존 출판
#   키워드: ['독립', '설명', '의존', '초보자', '혼자', '과정', '구체', '예시', '기분', '마음']
# --------------------
# Book 4: A ROOM OF FACE TO FACE
#   키워드: ['작업', '사진', '다른', '여러', '기획', '메이크업', '보정', '모델', '작업실', '공간']
# --------------------
# Book 5: Savemyself09!
#   키워드: ['일기장', '동안', '굳이', '보아', '마음', '전달', '직접', '본문', '구성', '하루']
# --------------------

# %% [markdown]
# ## 추출된 키워드 정리 및 표시
#
# ### Subtask:
# 추출된 키워드를 정리하고, 각 책별 키워드 또는 전체 키워드 목록을 보기 좋게 표시합니다.

# %%
# 각 책별로 추출된 키워드를 책 제목과 함께 보기 좋게 출력합니다.
print("--- 각 책별 추출 키워드 ---")
for book in all_book_details:
    title = book.get('제목', '제목 없음')
    keywords = book.get('키워드', [])
    print(f"제목: {title}")
    if keywords:
        print(f"  키워드: {', '.join(keywords)}")
    else:
        print("  키워드: 추출된 키워드 없음")
    print("-" * 20)
# Out:
# --- 각 책별 추출 키워드 ---
# 제목: 이러나저러나 불편한 거야 불편한 건
#   키워드: 감정, 가지, 이름, 마주, 그대로, 자주, 기록, 불안, 후회, 무기
# --------------------
# 제목: 불안과 밤 산책
#   키워드: 불안, 산책, 기록, 당신, 하루, 마음, 내기, 아침, 문득, 우울
# --------------------
# 제목: 속속들이 독립출판 알고 보니 의존 출판
#   키워드: 독립, 설명, 의존, 초보자, 혼자, 과정, 구체, 예시, 기분, 마음
# --------------------
# 제목: A ROOM OF FACE TO FACE
#   키워드: 작업, 사진, 다른, 여러, 기획, 메이크업, 보정, 모델, 작업실, 공간
# --------------------
# 제목: Savemyself09!
#   키워드: 일기장, 동안, 굳이, 보아, 마음, 전달, 직접, 본문, 구성, 하루
# --------------------
# 제목: (은/는/이/가) 당신을 사랑한다
#   키워드: 사랑, 당신, 순간, 목격, 마주, 이름, 괄호, 쫗는, 종착, 바로
# --------------------
# 제목: 반짝이는 나의 계절
#   키워드: 계절, 그늘, 볕뉘, 그녀, 사랑, 이별, 자리, 위로, 브런치, 시작
# --------------------
# 제목: 기숙사에 재고만이 쌓였습니다
#   키워드: 재고, 기숙사, 시간, 기록, 처음, 농담, 설명, 문장, 러시아, 도전
# --------------------
# 제목: 아름다운 이 세상은 우리를 시인으로 만들었지
#   키워드: 사랑, 세상, 시인, 위로, 공감
# --------------------
# 제목: 오늘의문예비평 136호
#   키워드: 비평, 문예비평, 문화, 오늘, 부산, 창간, 전국, 유일, 문지, 동안
# --------------------
# 제목: MTB로 백두대간과 9정맥
#   키워드: 기록, 정신, 한계, 고통, 여정, 덕분, 평소, 탄생, 체력, 극복
# --------------------
# 제목: 일상의 재발견
#   키워드: 일상, 컨셉, 노하우, 발견, 당신, 확신, 매달, 라이프스타일, 하나, 질문
# --------------------
# 제목: 잘 될 거야 같은 소리 하네
#   키워드: 세트, 도덕, 합리, 행동, 소리, 인생, 홀로, 가지, 자력, 돌파
# --------------------
# 제목: 나는 괴물입니다
#   키워드: 괴물, 미노타우로스, 영웅, 혼자, 어째서, 주인공, 아무, 신화, 황소, 미궁
# --------------------
# 제목: 작은방 한켠 나의 트레킹 가방
#   키워드: 트레킹, 산티아고, 시간, 주의, 아이, 걷기, 시작, 주간, 엄마, 육아
# --------------------
# 제목: CONCEPTZINE vol.124
#   키워드: 등산, 고민, 마음, 팀원, 그녀, 문화, 중간, 미션, 캠프, 머릿속
# --------------------
# 제목: 부라보 마이 라이프
#   키워드: 부라보, 라이프, 컬러, 링북, 마이, 응원, 찬사, 메세지, 그림, 조각
# --------------------
# 제목: 아날로그
#   키워드: 아날로그, 스마트폰, 핸드폰, 절대, 남자, 디지털, 시대, 여자, 미니, 엉뚱
# --------------------
# 제목: 마음챙김 플라워 힐링북
#   키워드: 마음, 힐링, 플라워, 자신, 구성, 적극, 삽입, 색칠, 또한, 심리
# --------------------
# 제목: 울지마
#   키워드: 위로, 플립, 순간, 이미지, 손끝, 절망, 어린이, 미술관, 어둠, 미약
# --------------------
# 제목: Small Brand, High value
#   키워드: 브랜드, 브랜딩, 스몰, 소개, 가지, 가치, 이해, 중인, 영감, 다른
# --------------------
# 제목: 일시 정지 후 재생
#   키워드: 시간, 마음, 일시, 정지, 재생, 기록, 전하, 당신, 하루, 쉼표
# --------------------
# 제목: 엉망진창인채로 40대, 오히려 좋아
#   키워드: 엉망, 진창, 이름, 오히려, 대가, 생각, 경험, 사랑, 미리, 시작
# --------------------
# 제목: 외계행성 다방유랑기
#   키워드: 외계, 디저트, 종족, 선희, 친구, 마리, 외계행성, 다방, 유랑, 세기
# --------------------
# 제목: 즉흥 연주를 위한 실전 코드 사전
#   키워드: 코드, 실전, 주법, 연주, 원리, 파워코드, 수록, 모양, 성음, 초보자
# --------------------
# 제목: 기타 연습 가이드북
#   키워드: 기타, 연습, 노하우, 치기, 경력, 유튜버, 부리, 매일, 일지, 가이드북
# --------------------
# 제목: 조각난 기억, 사랑으로 남다
#   키워드: 기억, 치매, 조각, 어르신, 사랑, 사회, 인간, 현실, 가족, 슬픔
# --------------------
# 제목: 사탄탱고: 벨라 타르에 들어가기 앞서
#   키워드: 벨라, 타르, 사탄, 탱고, 영화, 감독, 앞서, 상영, 기념, 생애
# --------------------
# 제목: Two Of A Kind
#   키워드: 여행, 강릉, 사진, 주변, 시선, 동안, 발견, 강원도, 번의, 사흘
# --------------------
# 제목: 퇴사 후, 치앙마이
#   키워드: 여행, 치앙마이, 퇴사, 기록, 마음, 치유, 사진, 산문, 날씨, 마주
# --------------------
# 제목: 기억나무
#   키워드: 창성, 사랑, 아빠, 기억, 하늘나라, 나무, 코넬, 리아드, 랑게, 증후군
# --------------------
# 제목: 새벽 죽음 연습
#   키워드: 죽음, 연습, 새벽, 하단, 그것, 무엇, 표본, 목적지, 위로, 전개
# --------------------
# 제목: 뇌경색 환자의 좌충우돌 1인 출판사 창업기
#   키워드: 출판사, 뇌경색, 좌충우돌, 창업, 환자, 노하우, 세상, 전하, 누군가, 용기
# --------------------
# 제목: 로컬 매거진 인천 스펙타클(spectacle) : 05 술술 읽히는 인천의 술
#   키워드: 인천, 취향, 로컬, 도시, 누구, 술집, 주류, 문화, 장면, 공간
# --------------------
# 제목: 넘어졌던 자리에서 다시 걸을 수 있다면 정말 괜찮습니다
#   키워드: 당신, 선택, 누구, 자리, 다짐, 마음, 하루, 위로, 그대로, 오늘
# --------------------
# 제목: 로자 룩셈부르크
#   키워드: 로자, 룩셈부르크, 그녀, 팔레스타인, 페미니스트, 평화, 혁명, 군인, 살해, 지지
# --------------------
# 제목: 여름으로 지어진 곳
#   키워드: 공간, 여름, 사랑, 호수, 누구, 정원, 다림, 초원, 사진관, 리쯔웨이
# --------------------
# 제목: 닻
#   키워드: 기억, 고통, 유년, 노년, 감정, 통찰, 마주, 파편, 시가, 심리학
# --------------------
# 제목: 알을 두고 온 새의 마음
#   키워드: 마음, 하늘, 술래, 둥지, 숨바꼭질, 마리, 어쩌면, 가치, 아파트, 선풍기
# --------------------
# 제목: 살아있는 보물지도의 비밀
#   키워드: 그림, 시선, 여행, 표현, 사랑, 송성민, 어린이, 즐거움, 영어, 세계
# --------------------
# 제목: 들켜도 망하지 않았으면 좋겠다
#   키워드: 소개, 사랑, 마음, 지구인, 미동, 과정, 무어, 입밖, 엮었습니, 일상
# --------------------
# 제목: 긍정샐러드
#   키워드: 감정, 샐러드, 긍정, 균형, 경험, 레시피, 다이어터, 변화, 구성, 비유
# --------------------
# 제목: 파란인
#   키워드: 파란, 무엇, 위치, 단언, 당신, 사랑, 멀리, 자의
# --------------------
# 제목: 파도에 지워진 어부의 시
#   키워드: 파도, 상도, 어부, 저녁, 노을, 서서히, 시작, 시간, 주저, 바다
# --------------------
# 제목: 달팽이의 슬픔
#   키워드: 슬픔, 동화, 난키, 다섯, 달팽이, 일본, 안데르센, 선별, 나무, 본연
# --------------------
# 제목: 그래서... 제목이 뭔데? 2
#   키워드: 제목, 그림, 완성, 전세계, 주목, 이해, 상상력, 표현, 자극, 인문학
# --------------------
# 제목: 내 이야기가 책이 되는 순간
#   키워드: 순간, 처음, 자신, 정리, 듀스, 오디션, 시작, 완성, 세상, 머릿속
# --------------------
# 제목: 고로 존재한다
#   키워드: 생각, 기록, 일상, 노트, 고로, 존재, 사건, 일반, 다이어리, 내면
# --------------------
# 제목: 사유하라
#   키워드: 사유, 철학, 실천, 탄핵, 심판, 이후, 혼란, 갈등, 철학자, 순의
# --------------------
# 제목: 쓰기로 다시 시작
#   키워드: 쓰기, 시작, 엄마, 글쓰기, 마케터, 기획, 디렉터, 주체, 일상, 여성
# --------------------
# 제목: 자유형을 완벽하게 하는 방법
#   키워드: 자유형, 이영, 수영, 강습, 피아노, 해은, 방법, 수영장, 희망, 미래
# --------------------
# 제목: 대머리는 수영모를 쓰지 않는다
#   키워드: 대머리, 방송, 예능, 일인, 가구, 일상, 조각, 수영모, 좌충우돌, 본업
# --------------------
# 제목: 강아지책
#   키워드: 강아지, 유기견, 반려견, 사랑, 선택, 출신, 마리, 서사, 메시지, 전달
# --------------------
# 제목: 서성이는 발걸음
#   키워드: 존재, 형태, 순간, 위안, 찰나, 과정, 노력, 즉흥, 음악, 그림
# --------------------
# 제목: 파도보다 더 높이
#   키워드: 파도, 좌절, 김준희, 높이, 사회, 슬픔, 실패, 겹겹, 충만, 세계
# --------------------
# 제목: 하루와 클로버
#   키워드: 하루, 감정, 단지, 주인공, 다른, 클로버, 과정, 성장, 변화, 행복
# --------------------
# 제목: 색을 짓다
#   키워드: 유슬이, 세상, 여행, 상상, 선천, 시각장애인, 모습, 궁금증, 색칠, 동생
# --------------------
# 제목: 마음을 담아, 당신에게 응원을 건네요
#   키워드: 사연, 응원, 익명, 답장, 마음, 당신, 보고, 달라, 나날, 고단
# --------------------
# 제목: 굳이, 서울
#   키워드: 서울, 굳이, 무아레, 서점, 동경, 드림, 안고, 도착, 모습, 도서
# --------------------
# 제목: 나의 독립출판은 지속될 수 있을까
#   키워드: 독립, 지속, 입문, 주년, 정재, 솔직, 고백, 활동, 출판사, 설립
# --------------------
# 제목: 늘 같은 자리를 맴도는 한낮의 달처럼
#   키워드: 한낮, 자리, 맴도, 여행, 보이지, 기록, 오늘, 지금, 당신
# --------------------
# 제목: CONCEPTZINE vol.123
#   키워드: 경청, 누군가, 생각, 방송, 절절, 시간, 회의, 의견, 예능, 장면
# --------------------
# 제목: 저도 알고 싶지 않았습니다
#   키워드: 다섯, 갑자기, 데리, 하루하루, 뚜벅뚜벅, 가지, 중반, 초반, 중년, 초입
# --------------------
# 제목: 우리가 슬쩍 본 도시 스톡홀름, 헬싱키
#   키워드: 도시, 스톡홀름, 헬싱키, 인상, 기록, 보고, 시리즈, 공부, 계획, 여행자
# --------------------
# 제목: 용기를 내어 일어서라
#   키워드: 강론, 하느님, 여정, 신부, 믿음, 사제, 서품, 만남, 실천, 용기
# --------------------
# 제목: 우울하기엔 오늘의 내가 너무 빛나서
#   키워드: 여행, 모습, 용기, 생각, 방황, 시기, 세상, 무엇, 길이, 자신
# --------------------
# 제목: 아임 이너프 - I'm enough
#   키워드: 너프, 순간, 아이, 자신, 색채, 그로, 다른, 기준, 본연, 모습
# --------------------
# 제목: 엄마로 눈부신 순간
#   키워드: 엄마, 순간, 기록, 아이, 기억, 아기, 육아, 매일, 자신, 꾹꾹
# --------------------
# 제목: 당신을 응원합니다 당신이 최고입니다 자랑스럽습니다
#   키워드: 당신, 누군가, 응원, 순간, 마음, 누구, 최고, 먼저, 존재, 세상
# --------------------
# 제목: 몽매한 풀잎은 그 봄을 기억한다
#   키워드: 아내, 몽매, 풀잎, 기억, 아픔, 기록, 간직, 사랑, 사람과, 오늘
# --------------------
# 제목: 28일 플랜
#   키워드: 생리, 주기, 플랜, 여성, 자신, 활용, 단계, 리듬, 자기계발, 변화
# --------------------
# 제목: 초보 사장의 특별한맛주식회사 경영기
#   키워드: 사장, 초보, 회사, 주식회사, 가업, 고추장, 공장, 경영, 정보, 영기
# --------------------
# 제목: 대통령제의 종언
#   키워드: 대통령제, 현행, 의회, 내란, 기초, 제도, 결함, 근본, 의문, 비례대표제
# --------------------
# 제목: 빌어먹을 필라테스
#   키워드: 운동, 빌어먹을, 필라테스, 댁네, 근육, 거북목, 허리, 피로, 증발, 주말
# --------------------
# 제목: 어른이 되어 가는 과정
#   키워드: 사랑, 어른, 과정, 무엇, 표현, 대가, 지금, 모습, 물음, 대답
# --------------------
# 제목: 리타의 산책
#   키워드: 자연, 산책, 존재, 내면, 리타, 사유, 여름, 교감, 순간, 호흡
# --------------------
# 제목: 메무와 무지개 탐험
#   키워드: 무지개, 메무, 포기, 탐험, 여정, 보물, 너머, 모험, 도전, 아이
# --------------------
# 제목: 잠적
#   키워드: 잠적, 창작, 기록, 문집, 주간, 대화, 사적, 독립, 개구리, 정기
# --------------------
# 제목: 내가 지금, 여기
#   키워드: 위로, 지금, 여기, 도시, 파리, 뉴욕, 런던, 여행, 응원, 낭만
# --------------------
# 제목: 마음의 위상
#   키워드: 요정, 마음, 꽃말, 달맞이꽃, 기다림, 마법, 사이, 조합, 그래픽, 위상
# --------------------
# 제목: 청소 (월간옥키52)
#   키워드: 청소, 행동, 옥키, 수행, 매일, 월간, 생각, 일면, 무언가, 정돈
# --------------------
# 제목: WALK TOKYO
#   키워드: 사진, 도쿄, 명의, 필름, 하나, 서른, 사진가, 참여, 풍경, 도시
# --------------------
# 제목: WALK PARIS
#   키워드: 사진, 파리, 필름, 카메라, 하나, 서른, 사진가, 풍경, 도시, 여행
# --------------------
# 제목: 까미노의 말
#   키워드: 미노, 순례, 생각, 이십, 산티아고, 걷기, 도전, 여행, 킬로, 짊어지
# --------------------
# 제목: 염재현의 지구촌 이야기
#   키워드: 지구촌, 감성, 글로벌, 세대, 투자, 재현, 펀드매니저, 세상, 모습, 문화
# --------------------
# 제목: 정말 잘 지내나요 사실 난 울고 있는데
#   키워드: 엄마, 점점, 세상, 절망, 대답, 사실, 누군가, 슬픔, 경찰관, 아버지
# --------------------
# 제목: 극야일기
#   키워드: 극야, 마을, 이상, 계속, 일기, 북위, 서경, 위치, 미국, 북단
# --------------------
# 제목: 만다라로 자기 돌봄
#   키워드: 욕구, 만다라, 자기, 무엇, 먼저, 갈등, 자신, 타인, 대인관계, 하나
# --------------------
# 제목: 네가 원한다면 망설일 필요 없어
#   키워드: 필요, 나로, 소리, 응원, 내면, 당신, 위로, 용기, 메시지, 서울
# --------------------
# 제목: 쓸수록 돈이 된다
#   키워드: 콘텐츠, 강점, 발견, 글쓰기, 방법, 결코, 쓰기, 노하우, 누구
# --------------------
# 제목: 갑상선암에 걸리면 스카프 쇼핑부터 하는 게 좋다
#   키워드: 갑상선암, 스카프, 쇼핑, 여기, 불행, 일기, 질병, 종류, 아픔, 강도
# --------------------
# 제목: 훌쩍대지 말고 훌쩍 떠나
#   키워드: 훌쩍, 낯선, 바레인, 광고, 회사, 카피라이터, 탈출, 이름, 한국어, 선생님
# --------------------
# 제목: 커피 앞에서 쓰기
#   키워드: 수첩, 일상, 커피, 영감, 산문, 쓰기, 문장, 오늘, 수집, 기록
# --------------------
# 제목: 내가 널 생각할 때마다 별들이 빛난다면
#   키워드: 당신, 사랑, 감성, 마음, 때로는, 아픔, 마음속, 감정, 별처럼, 봄볕
# --------------------
# 제목: 혼잣말 모임
#   키워드: 정연, 윤아, 혼잣말, 모임, 회사, 주임, 신입, 자신, 감정, 억압
# --------------------
# 제목: 도대체 책방이 뭐라고
#   키워드: 책방, 매탄동, 지기, 수원, 의미, 선택, 투기, 안간힘, 운영, 시작
# --------------------
# 제목: 개와 고양이, 오래된 신문을 펼치다
#   키워드: 신문, 고양이, 동물, 시대, 사회, 당시, 인간, 관계, 자료, 도서
# --------------------
# 제목: Fragments of the Past
#   키워드: 사진, 인간, 반려동물, 흑백, 사랑, 관계, 순간, 감동, 세기, 고양이
# --------------------
# 제목: 수상한 양말
#   키워드: 아이, 마음, 수상한, 양말, 동네, 시절, 광주, 대표, 키즈, 브랜드
# --------------------
# 제목: CONCEPTZINE vol.122
#   키워드: 생각, 얼마나, 표현, 자기, 보고, 자신, 관리, 미팅, 모습, 손톱
# --------------------
# 제목: 도망치듯 사랑을 말한다면
#   키워드: 사랑, 로부터, 세상, 그동안, 혐오, 마음, 라면, 미움, 때로는, 존재
# --------------------
# 제목: 유독 내가 싫은 날
#   키워드: 청소년, 유독, 마음, 위로, 샤워, 시간, 이상, 도망, 아무, 보고
# --------------------
# 제목: 아차어차여차하면 달라지는 단어들 : 일상의 재구성
#   키워드: 단어, 사전, 아차, 오해, 정의, 때문, 여차하면, 일상, 구성, 살다보면
# --------------------
# 제목: 아차어차여차하면 달라지는 단어들 : 관계의 재구성
#   키워드: 단어, 사전, 아차, 관계, 오해, 정의, 때문, 여차하면, 구성, 살다보면
# --------------------
# 제목: 먹는다의 디자인
#   키워드: 디자인, 음식, 경험, 가지, 매우, 이해, 방식, 마음, 인상, 매력
# --------------------
# 제목: 적어도 둘이라 좋아
#   키워드: 글쓰기, 글감, 여정, 일상, 내면, 감각, 주간, 호흡, 빈자리, 마련
# --------------------
# 제목: 4주완성! 쉬운데 그럴싸한 디지털드로잉
#   키워드: 드로잉, 디지털, 동안, 완성, 주일, 태블릿, 기초, 용법, 일주일, 차별
# --------------------
# 제목: 4주완성! 쉬운데 그럴싸한 디지털드로잉
#   키워드: 드로잉, 디지털, 완성, 주간, 그릴, 태블릿, 기초, 용법, 일주일, 동안
# --------------------
# 제목: 열매를 맺기 위해 준비하는
#   키워드: 열매, 체리, 청소년, 시절, 준비, 자서전, 프로젝트, 개성, 연대, 때문
# --------------------
# 제목: 해를 쫓는 아이들
#   키워드: 상징, 신화, 소년, 소녀, 한쪽, 의견, 아이, 시간, 누군가, 가요
# --------------------
# 제목: 머어얼리
#   키워드: 어디, 머리, 전하, 어딘가, 마음, 세상, 생명, 응원, 무리, 개미
# --------------------
# 제목: 날씨 '소나기'
#   키워드: 바다, 이별, 사랑, 감정, 그녀, 날씨, 소나기, 주인공, 하나, 부로
# --------------------
# 제목: 깨어난 자유
#   키워드: 자유, 사회, 철학, 깊이, 주제, 규범, 자신, 존재, 의미, 여정
# --------------------
# 제목: 매달리는 기쁨
#   키워드: 기쁨, 계속, 마음, 책방, 운영, 폐업, 고민, 인스타그램, 방학, 알리
# --------------------
# 제목: 마음을 안는 마음
#   키워드: 마음, 마주, 마치, 길목, 퇴사, 홀로, 독립, 혼자, 누군가, 직장
# --------------------
# 제목: 樂, STEP - 요즘엔 스윙댄스를 추고 있습니다
#   키워드: 스윙댄스, 스텝, 리듬, 요즘, 앤솔로지, 일상, 흔적, 당신, 음악, 순간
# --------------------
# 제목: 산책가자
#   키워드: 산책, 한강, 하루, 밥풀, 매일, 서울, 행복, 아침, 저녁, 반려견
# --------------------
# 제목: 일기를 쓰려는데 아무일도 없었어
#   키워드: 영감, 기록, 일기, 일기도, 하나, 장르, 하루, 과거, 현재, 미래
# --------------------
# 제목: 떠나고, 남았다
#   키워드: 도전, 당신, 의미, 질문, 중년, 고민, 자녀, 부모, 스리랑카, 기록
# --------------------
# 제목: 어쩐지 제주에 오고 싶었어
#   키워드: 제주, 여섯, 루틴, 소풍, 자연, 어쩐지, 개월, 하루, 기록, 시작
# --------------------
